# %% [markdown]
# # Setup

# %%
USE_GPU = True

# %%
import os
import shutil
import sys
import copy

import pandas as pd
import numpy as np

# Append the custom libraries to system path
sys.path.append("/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project")

# Configure device
if not USE_GPU:
    print("Using CPU to train")
    os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
else:
    print("Using GPU to train")

from src.config_reader import ConfigurationReader
from src.data_utils import mice
from src.plot import plot_1_data
# Out:
# Using GPU to train

# %%
conf = ConfigurationReader("/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/model_params.json").data
print(conf)

# Clear all temp folders
def cleanDir(input_dir):
    if os.path.exists(input_dir):
        shutil.rmtree(input_dir)
    os.makedirs(input_dir)

cleanDir(conf["workspace"]["data_by_location_dir"])
# Out:
# {'dataset': {'aod2022': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/MatchingData2022.xlsx', 'target_start_date': '2022-01-01', 'target_end_date': '2022-12-31'}, 'aod2021': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/aod_data_daily.csv', 'target_start_date': '2021-01-01', 'target_end_date': '2021-12-31'}, 'mpair': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/MPair.csv', 'target_start_date': '2021-01-01', 'target_end_date': '2022-12-31', 'station_2022_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/station2022.csv', 'station_2018_2021_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/station2018-2021.csv', 'merged_data_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/mpair_merged.csv', 'merged_data_dir_all_locations': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/mpair_merged_all_locations.csv', 'merged_data_dir_all_locations_2018_2022': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/mpair_merged_all_locations_2018_2022.csv'}, 'cmaq': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/concentration_station'}, 'pm2022': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/quan-trac/2022'}, 'pm2021': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/quan-trac/2021'}}, 'workspace': {'model_info_dir': '/le_thanh_van_118/workspace/hiep_workspace/model_info', 'model_checkpoints_dir': '/le_thanh_van_118/workspace/hiep_workspace/model_checkpoints', 'data_by_location_dir': '/le_thanh_van_118/workspace/hiep_workspace/data_by_location', 'data_by_station_dir': '/le_thanh_van_118/workspace/hiep_workspace/data_by_station', 'data_statistic_dir': '/le_thanh_van_118/workspace/hiep_workspace/data_statistic', 'best_reduction_models_dir': '/le_thanh_van_118/workspace/hiep_workspace/best_reduction_models', 'best_reduced_data': '/le_thanh_van_118/workspace/hiep_workspace/best_reduced_data'}, 'prediction': {'n_past': 7, 'n_future': 1, 'epochs': 50, 'batch_size': 128}, 'reduction': {'n_past': 7, 'n_future': 7, 'epochs': 50, 'batch_size': 128, 'min_number_of_features': 10}}

# %% [markdown]
# # Load dataset

# %% [markdown]
# ## MPair.csv

# %% [markdown]
# ### Read CSV

# %%
df_mpair_raw = pd.read_csv(conf["dataset"]["mpair"]["file_dir"])
df_mpair_raw
# Out:
#           i   j        lat         lon        time     PM25_3km          TMP  \
# 0         0   0  11.149747  106.300443  2018-01-01 -9999.000000 -9999.000000
# 1         0   1  11.149747  106.323330  2018-01-01 -9999.000000 -9999.000000
# 2         0   2  11.149747  106.346217  2018-01-01 -9999.000000 -9999.000000
# 3         0   3  11.149747  106.369103  2018-01-01    24.740000    25.460614
# 4         0   4  11.149747  106.391990  2018-01-01    23.760931    25.462688
# ...      ..  ..        ...         ...         ...          ...          ...
# 2236845  34  30  10.385233  106.987043  2022-12-31          NaN    25.815809
# 2236846  34  31  10.385233  107.009930  2022-12-31          NaN    25.815809
# 2236847  34  32  10.385233  107.032816  2022-12-31 -9999.000000    25.601173
# 2236848  34  33  10.385233  107.055703  2022-12-31 -9999.000000    25.560753
# 2236849  34  34  10.385233  107.078590  2022-12-31 -9999.000000    25.834951
#
#                   RH         HPBL         WSPD  ...      NEAR_DIST  \
# 0       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 1       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 2       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 3          65.144661     2.448070     2.448070  ...   7.265194e+01
# 4          65.080498     2.438784     2.438784  ...   1.107789e+02
# ...              ...          ...          ...  ...            ...
# 2236845    74.737156   207.873199     3.124345  ...   3.072120e+03
# 2236846    75.000397   207.873199     3.215876  ...   4.355371e+03
# 2236847 -9999.000000   142.227615 -9999.000000  ... -1.797693e+308
# 2236848 -9999.000000   129.865280 -9999.000000  ... -1.797693e+308
# 2236849 -9999.000000   284.036316 -9999.000000  ... -1.797693e+308
#
#              BARELAND       BUILTUP      CROPLAND      GRASSLAND  \
# 0        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 1        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 3        14453.144036  30347.516088  54101.838731  203551.710735
# 4         4569.189136  21119.949784  76052.614180  231046.865089
# ...               ...           ...           ...            ...
# 2236845  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236846  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236847  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236848  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236849  -9999.000000  -9999.000000  -9999.000000   -9999.000000
#
#              TREECOVER         WATER    NDVI          AOD      AIMODEL
# 0         -9999.000000  -9999.000000 -9999.0 -9999.000000 -9999.000000
# 1         -9999.000000  -9999.000000 -9999.0 -9999.000000 -9999.000000
# 2         -9999.000000  -9999.000000 -9999.0     0.156327 -9999.000000
# 3        683877.574149  13604.234765     NaN     0.167487 -9999.000000
# 4        662859.174184   4308.164827     NaN     0.141881 -9999.000000
# ...                ...           ...     ...          ...          ...
# 2236845   -9999.000000  -9999.000000     NaN -9999.000000    14.998473
# 2236846   -9999.000000  -9999.000000     NaN -9999.000000    15.201084
# 2236847   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
# 2236848   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
# 2236849   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
#
# [2236850 rows x 25 columns]

# %%
df_mpair_raw.columns
# Out:
# Index(['i', 'j', 'lat', 'lon', 'time', 'PM25_3km', 'TMP', 'RH', 'HPBL', 'WSPD',
#        'PRES2M', 'POP', 'ROAD_DEN_1km', 'ROAD_LEN_1km', 'PRIM_ROAD_LEN_1km',
#        'NEAR_DIST', 'BARELAND', 'BUILTUP', 'CROPLAND', 'GRASSLAND',
#        'TREECOVER', 'WATER', 'NDVI', 'AOD', 'AIMODEL'],
#       dtype='object')

# %% [markdown]
# ### Handle metadata

# %%
# Convert "time" columns to Pandas datetime
df_mpair_raw = df_mpair_raw.assign(time=pd.to_datetime(df_mpair_raw["time"]))

# Lower case all column names
df_mpair_raw = df_mpair_raw.rename(columns={name: name.lower() for name in df_mpair_raw.columns})

# Print
df_mpair_raw
# Out:
#           i   j        lat         lon       time     pm25_3km          tmp  \
# 0         0   0  11.149747  106.300443 2018-01-01 -9999.000000 -9999.000000
# 1         0   1  11.149747  106.323330 2018-01-01 -9999.000000 -9999.000000
# 2         0   2  11.149747  106.346217 2018-01-01 -9999.000000 -9999.000000
# 3         0   3  11.149747  106.369103 2018-01-01    24.740000    25.460614
# 4         0   4  11.149747  106.391990 2018-01-01    23.760931    25.462688
# ...      ..  ..        ...         ...        ...          ...          ...
# 2236845  34  30  10.385233  106.987043 2022-12-31          NaN    25.815809
# 2236846  34  31  10.385233  107.009930 2022-12-31          NaN    25.815809
# 2236847  34  32  10.385233  107.032816 2022-12-31 -9999.000000    25.601173
# 2236848  34  33  10.385233  107.055703 2022-12-31 -9999.000000    25.560753
# 2236849  34  34  10.385233  107.078590 2022-12-31 -9999.000000    25.834951
#
#                   rh         hpbl         wspd  ...      near_dist  \
# 0       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 1       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 2       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 3          65.144661     2.448070     2.448070  ...   7.265194e+01
# 4          65.080498     2.438784     2.438784  ...   1.107789e+02
# ...              ...          ...          ...  ...            ...
# 2236845    74.737156   207.873199     3.124345  ...   3.072120e+03
# 2236846    75.000397   207.873199     3.215876  ...   4.355371e+03
# 2236847 -9999.000000   142.227615 -9999.000000  ... -1.797693e+308
# 2236848 -9999.000000   129.865280 -9999.000000  ... -1.797693e+308
# 2236849 -9999.000000   284.036316 -9999.000000  ... -1.797693e+308
#
#              bareland       builtup      cropland      grassland  \
# 0        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 1        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 3        14453.144036  30347.516088  54101.838731  203551.710735
# 4         4569.189136  21119.949784  76052.614180  231046.865089
# ...               ...           ...           ...            ...
# 2236845  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236846  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236847  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236848  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236849  -9999.000000  -9999.000000  -9999.000000   -9999.000000
#
#              treecover         water    ndvi          aod      aimodel
# 0         -9999.000000  -9999.000000 -9999.0 -9999.000000 -9999.000000
# 1         -9999.000000  -9999.000000 -9999.0 -9999.000000 -9999.000000
# 2         -9999.000000  -9999.000000 -9999.0     0.156327 -9999.000000
# 3        683877.574149  13604.234765     NaN     0.167487 -9999.000000
# 4        662859.174184   4308.164827     NaN     0.141881 -9999.000000
# ...                ...           ...     ...          ...          ...
# 2236845   -9999.000000  -9999.000000     NaN -9999.000000    14.998473
# 2236846   -9999.000000  -9999.000000     NaN -9999.000000    15.201084
# 2236847   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
# 2236848   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
# 2236849   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
#
# [2236850 rows x 25 columns]

# %% [markdown]
# ### Drop unnecessary columns

# %%
# Drop the columns because they are not in the matching data 2021 2022
# Use "python set" to check if the columns to drop are actually in the dataset
columns_to_drop = set(["aimodel", "pres2m", "road_len_1km"]) & set(df_mpair_raw.columns)
print(columns_to_drop)
df_mpair_raw = df_mpair_raw.drop(columns=columns_to_drop)
df_mpair_raw
# Out:
# {'aimodel', 'pres2m', 'road_len_1km'}
#           i   j        lat         lon       time     pm25_3km          tmp  \
# 0         0   0  11.149747  106.300443 2018-01-01 -9999.000000 -9999.000000
# 1         0   1  11.149747  106.323330 2018-01-01 -9999.000000 -9999.000000
# 2         0   2  11.149747  106.346217 2018-01-01 -9999.000000 -9999.000000
# 3         0   3  11.149747  106.369103 2018-01-01    24.740000    25.460614
# 4         0   4  11.149747  106.391990 2018-01-01    23.760931    25.462688
# ...      ..  ..        ...         ...        ...          ...          ...
# 2236845  34  30  10.385233  106.987043 2022-12-31          NaN    25.815809
# 2236846  34  31  10.385233  107.009930 2022-12-31          NaN    25.815809
# 2236847  34  32  10.385233  107.032816 2022-12-31 -9999.000000    25.601173
# 2236848  34  33  10.385233  107.055703 2022-12-31 -9999.000000    25.560753
# 2236849  34  34  10.385233  107.078590 2022-12-31 -9999.000000    25.834951
#
#                   rh         hpbl         wspd  ...  prim_road_len_1km  \
# 0       -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 1       -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 2       -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 3          65.144661     2.448070     2.448070  ...                NaN
# 4          65.080498     2.438784     2.438784  ...                NaN
# ...              ...          ...          ...  ...                ...
# 2236845    74.737156   207.873199     3.124345  ...                NaN
# 2236846    75.000397   207.873199     3.215876  ...                NaN
# 2236847 -9999.000000   142.227615 -9999.000000  ...                0.0
# 2236848 -9999.000000   129.865280 -9999.000000  ...                0.0
# 2236849 -9999.000000   284.036316 -9999.000000  ...                0.0
#
#              near_dist      bareland       builtup      cropland  \
# 0       -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 1       -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2       -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 3         7.265194e+01  14453.144036  30347.516088  54101.838731
# 4         1.107789e+02   4569.189136  21119.949784  76052.614180
# ...                ...           ...           ...           ...
# 2236845   3.072120e+03  -9999.000000  -9999.000000  -9999.000000
# 2236846   4.355371e+03  -9999.000000  -9999.000000  -9999.000000
# 2236847 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2236848 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2236849 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
#
#              grassland      treecover         water    ndvi          aod
# 0         -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 1         -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 2         -9999.000000   -9999.000000  -9999.000000 -9999.0     0.156327
# 3        203551.710735  683877.574149  13604.234765     NaN     0.167487
# 4        231046.865089  662859.174184   4308.164827     NaN     0.141881
# ...                ...            ...           ...     ...          ...
# 2236845   -9999.000000   -9999.000000  -9999.000000     NaN -9999.000000
# 2236846   -9999.000000   -9999.000000  -9999.000000     NaN -9999.000000
# 2236847   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 2236848   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 2236849   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
#
# [2236850 rows x 22 columns]

# %% [markdown]
# ## station2018-2021.csv

# %% [markdown]
# ### Read CSV

# %%
df_station_2021 = pd.read_csv(conf["dataset"]["mpair"]["station_2018_2021_dir"])
df_station_2021
# Out:
#                   time   ID         Lon        Lat       pm25   i   j
# 0        1/1/2018 0:00  201  106.700606  10.783057  31.391304  16  17
# 1        1/1/2018 0:00  202  106.682027  10.762638  29.615625  17  17
# 2        1/1/2018 0:00  211  106.796200  10.870190        NaN  12  22
# 3        1/1/2018 0:00  212  106.617000  10.740760        NaN  18  14
# 4        1/1/2018 0:00  213  106.620500  10.816350        NaN  15  14
# ...                ...  ...         ...        ...        ...  ..  ..
# 11683  12/31/2021 0:00  212  106.617000  10.740760  20.100752  18  14
# 11684  12/31/2021 0:00  213  106.620500  10.816350  23.240539  15  14
# 11685  12/31/2021 0:00  214  106.717500  10.815570  20.549839  15  18
# 11686  12/31/2021 0:00  215  106.687900  10.776280        NaN  17  17
# 11687  12/31/2021 0:00  216  106.659300  10.780630  19.637165  16  16
#
# [11688 rows x 7 columns]

# %% [markdown]
# ### Handle metadata

# %%
# Convert "time" columns to Pandas datetime
df_station_2021 = df_station_2021.assign(time=pd.to_datetime(df_station_2021["time"]))

# Lower case all column names
df_station_2021 = df_station_2021.rename(columns={name: name.lower() for name in df_station_2021.columns})

# Rename "id" column to "station"
df_station_2021 = df_station_2021.rename(columns={"id": "station"})

# Sort data by station then time
df_station_2021.sort_values(by=["station", "time"], inplace=True, ignore_index=True)

# Print
df_station_2021
# Out:
#             time  station         lon        lat       pm25   i   j
# 0     2018-01-01      201  106.700606  10.783057  31.391304  16  17
# 1     2018-01-02      201  106.700606  10.783057  37.458333  16  17
# 2     2018-01-03      201  106.700606  10.783057  68.083333  16  17
# 3     2018-01-04      201  106.700606  10.783057  51.260870  16  17
# 4     2018-01-05      201  106.700606  10.783057  18.909091  16  17
# ...          ...      ...         ...        ...        ...  ..  ..
# 11683 2021-12-27      216  106.659300  10.780630  35.099753  16  16
# 11684 2021-12-28      216  106.659300  10.780630  24.782436  16  16
# 11685 2021-12-29      216  106.659300  10.780630  25.165238  16  16
# 11686 2021-12-30      216  106.659300  10.780630  16.656319  16  16
# 11687 2021-12-31      216  106.659300  10.780630  19.637165  16  16
#
# [11688 rows x 7 columns]

# %% [markdown]
# ### Check null

# %%
df_station_2021.isnull().sum()
# Out:
# time          0
# station       0
# lon           0
# lat           0
# pm25       8794
# i             0
# j             0
# dtype: int64

# %%
for station in df_station_2021["station"].unique():
    df_current_station = df_station_2021[df_station_2021["station"] == station]
    display(df_current_station.isnull().sum())
# Out:
# time        0
# station     0
# lon         0
# lat         0
# pm25       46
# i           0
# j           0
# dtype: int64
# time          0
# station       0
# lon           0
# lat           0
# pm25       1208
# i             0
# j             0
# dtype: int64
# time          0
# station       0
# lon           0
# lat           0
# pm25       1288
# i             0
# j             0
# dtype: int64
# time          0
# station       0
# lon           0
# lat           0
# pm25       1212
# i             0
# j             0
# dtype: int64
# time          0
# station       0
# lon           0
# lat           0
# pm25       1235
# i             0
# j             0
# dtype: int64
# time          0
# station       0
# lon           0
# lat           0
# pm25       1201
# i             0
# j             0
# dtype: int64
# time          0
# station       0
# lon           0
# lat           0
# pm25       1356
# i             0
# j             0
# dtype: int64
# time          0
# station       0
# lon           0
# lat           0
# pm25       1248
# i             0
# j             0
# dtype: int64

# %% [markdown]
# ### Filter out the invalid stations

# %%
'''
# Filter out the invalid station
all_valid_dfs = []
for station in df_station_2021["station"].unique():
    df_current_station = df_station_2021.loc[df_station_2021["station"] == station]
    number_of_missing_values = df_current_station["pm25"].isnull().sum()
    if number_of_missing_values >= 365:
        print(f"station {station} have {df_current_station['pm25'].isnull().sum()} missing values, skipping")
    else:
        print(f"station {station} have {df_current_station['pm25'].isnull().sum()} missing values")
        all_valid_dfs.append(df_current_station)
df_station_2021 = pd.concat(all_valid_dfs)
df_station_2021
'''
# Out:
# '\n# Filter out the invalid station\nall_valid_dfs = []\nfor station in df_station_2021["station"].unique():\n    df_current_station = df_station_2021.loc[df_station_2021["station"] == station]\n    number_of_missing_values = df_current_station["pm25"].isnull().sum()\n    if number_of_missing_values >= 365:\n        print(f"station {station} have {df_current_station[\'pm25\'].isnull().sum()} missing values, skipping")\n    else:\n        print(f"station {station} have {df_current_station[\'pm25\'].isnull().sum()} missing values")\n        all_valid_dfs.append(df_current_station)\ndf_station_2021 = pd.concat(all_valid_dfs)\ndf_station_2021\n'

# %% [markdown]
# ### Get the location-station map

# %%
# Get the location i, j of each station
all_stations = [int(ele) for ele in df_station_2021["station"].unique()]
station_ij_map_2021 = {}
for station in all_stations:
    i = int(df_station_2021.loc[df_station_2021["station"] == station]["i"].unique()[0])
    j = int(df_station_2021.loc[df_station_2021["station"] == station]["j"].unique()[0])
    station_ij_map_2021[station] = (i, j)
station_ij_map_2021
# Out:
# {201: (16, 17),
#  202: (17, 17),
#  211: (12, 22),
#  212: (18, 14),
#  213: (15, 14),
#  214: (15, 18),
#  215: (17, 17),
#  216: (16, 16)}

# %% [markdown]
# ## station2022.csv

# %% [markdown]
# ### Read CSV

# %%
df_station_2022 = pd.read_csv(conf["dataset"]["mpair"]["station_2022_dir"])
df_station_2022
# Out:
#            time  ID        lat         lon       pm25   i   j
# 0    2022-01-01  S4  10.815839  106.717396  23.768238  15  18
# 1    2022-01-01  S5  10.776415  106.687955  14.221014  17  17
# 2    2022-01-01  S6  10.780482  106.659511  21.405015  16  16
# 3    2022-01-01  S7  10.783456  106.700622  21.695652  16  17
# 4    2022-01-02  S4  10.815839  106.717396  22.154723  15  18
# ..          ...  ..        ...         ...        ...  ..  ..
# 993  2022-12-30  S6  10.780482  106.659511  33.091428  16  16
# 994  2022-12-30  S7  10.783456  106.700622  40.166667  16  17
# 995  2022-12-31  S4  10.815839  106.717396  27.879261  15  18
# 996  2022-12-31  S6  10.780482  106.659511  28.854069  16  16
# 997  2022-12-31  S7  10.783456  106.700622  33.958333  16  17
#
# [998 rows x 7 columns]

# %% [markdown]
# ### Handle metadata

# %%
# Convert "time" columns to Pandas datetime
df_station_2022 = df_station_2022.assign(time=pd.to_datetime(df_station_2022["time"]))

# Lower case all column names
df_station_2022 = df_station_2022.rename(columns={name: name.lower() for name in df_station_2022.columns})

# Rename "id" column to "station"
df_station_2022 = df_station_2022.rename(columns={"id": "station"})

# Print
df_station_2022
# Out:
#           time station        lat         lon       pm25   i   j
# 0   2022-01-01      S4  10.815839  106.717396  23.768238  15  18
# 1   2022-01-01      S5  10.776415  106.687955  14.221014  17  17
# 2   2022-01-01      S6  10.780482  106.659511  21.405015  16  16
# 3   2022-01-01      S7  10.783456  106.700622  21.695652  16  17
# 4   2022-01-02      S4  10.815839  106.717396  22.154723  15  18
# ..         ...     ...        ...         ...        ...  ..  ..
# 993 2022-12-30      S6  10.780482  106.659511  33.091428  16  16
# 994 2022-12-30      S7  10.783456  106.700622  40.166667  16  17
# 995 2022-12-31      S4  10.815839  106.717396  27.879261  15  18
# 996 2022-12-31      S6  10.780482  106.659511  28.854069  16  16
# 997 2022-12-31      S7  10.783456  106.700622  33.958333  16  17
#
# [998 rows x 7 columns]

# %% [markdown]
# ### Remap the stations to align with 2021 data

# %%
# Get the location i, j of each station
all_stations = df_station_2022["station"].unique()

station_ij_map_2022 = {}
for station in all_stations:
    i = int(df_station_2022.loc[df_station_2022["station"] == station]["i"].unique()[0])
    j = int(df_station_2022.loc[df_station_2022["station"] == station]["j"].unique()[0])
    station_ij_map_2022[station] = (i, j)
print(station_ij_map_2022)

# Generate the replace map
to_replace_station_map = {}
for station_2022, location_2022 in station_ij_map_2022.items():
    for station_2021, location_2021 in station_ij_map_2021.items():
        if location_2021 == location_2022:
            to_replace_station_map[station_2022] = station_2021
print(to_replace_station_map)

# Replace
df_station_2022.loc[:, ["station"]] = df_station_2022["station"].replace(to_replace=to_replace_station_map)

# Sort data by station then time
df_station_2022.sort_values(by=["station", "time"], inplace=True)

df_station_2022
# Out:
# {'S4': (15, 18), 'S5': (17, 17), 'S6': (16, 16), 'S7': (16, 17)}
# {'S4': 214, 'S5': 215, 'S6': 216, 'S7': 201}
# /tmp/ipykernel_1094125/413095497.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_station_2022.loc[:, ["station"]] = df_station_2022["station"].replace(to_replace=to_replace_station_map)
#           time station        lat         lon       pm25   i   j
# 3   2022-01-01     201  10.783456  106.700622  21.695652  16  17
# 7   2022-01-02     201  10.783456  106.700622  24.583333  16  17
# 11  2022-01-03     201  10.783456  106.700622  31.083333  16  17
# 15  2022-01-04     201  10.783456  106.700622  50.916667  16  17
# 19  2022-01-05     201  10.783456  106.700622  33.041667  16  17
# ..         ...     ...        ...         ...        ...  ..  ..
# 984 2022-12-27     216  10.780482  106.659511  39.659816  16  16
# 987 2022-12-28     216  10.780482  106.659511  44.679352  16  16
# 990 2022-12-29     216  10.780482  106.659511  30.724708  16  16
# 993 2022-12-30     216  10.780482  106.659511  33.091428  16  16
# 996 2022-12-31     216  10.780482  106.659511  28.854069  16  16
#
# [998 rows x 7 columns]

# %% [markdown]
# ### Check null

# %%
df_station_2022.isnull().sum()
# Out:
# time       0
# station    0
# lat        0
# lon        0
# pm25       0
# i          0
# j          0
# dtype: int64

# %%
correct_time_stamp = pd.date_range(conf["dataset"]["aod2022"]["target_start_date"], conf["dataset"]["aod2022"]["target_end_date"], freq="D")

all_reindex_dfs = []
# Padding missing data for each station
for station in df_station_2022["station"].unique():
    # Get current station
    df_current_station = df_station_2022.loc[df_station_2022["station"] == station]

    # Set "time" column as index first
    # Then reindex with the correct date range
    # This will fill in the missing timestamp
    df_current_station.set_index("time", inplace=True)
    df_current_station = df_current_station.reindex(correct_time_stamp)

    # Fill the static data
    for feature in ["station", "lat", "lon", "i", "j"]:
        df_current_station[feature] = df_current_station[feature].iloc[0]

    # Append data
    print(f"station = {station}, count = {len(df_current_station)}, start_date = {df_current_station.index[0]}, end_date = {df_current_station.index[-1]}")
    all_reindex_dfs.append(df_current_station.reset_index(names="time"))

# Combine all data
df_station_2022 = pd.concat(all_reindex_dfs).reset_index(drop=True)
df_station_2022
# Out:
# station = 201, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
# station = 214, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
# station = 215, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
# station = 216, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
#            time  station        lat         lon       pm25     i     j
# 0    2022-01-01      201  10.783456  106.700622  21.695652  16.0  17.0
# 1    2022-01-02      201  10.783456  106.700622  24.583333  16.0  17.0
# 2    2022-01-03      201  10.783456  106.700622  31.083333  16.0  17.0
# 3    2022-01-04      201  10.783456  106.700622  50.916667  16.0  17.0
# 4    2022-01-05      201  10.783456  106.700622  33.041667  16.0  17.0
# ...         ...      ...        ...         ...        ...   ...   ...
# 1455 2022-12-27      216  10.780482  106.659511  39.659816  16.0  16.0
# 1456 2022-12-28      216  10.780482  106.659511  44.679352  16.0  16.0
# 1457 2022-12-29      216  10.780482  106.659511  30.724708  16.0  16.0
# 1458 2022-12-30      216  10.780482  106.659511  33.091428  16.0  16.0
# 1459 2022-12-31      216  10.780482  106.659511  28.854069  16.0  16.0
#
# [1460 rows x 7 columns]

# %% [markdown]
# # Combine 2 station data

# %% [markdown]
# ## Check stations for each year

# %%
display(df_station_2021["station"].unique())
display(df_station_2022["station"].unique())
# Out:
# array([201, 202, 211, 212, 213, 214, 215, 216])
# array([201, 214, 215, 216])

# %% [markdown]
# ## Start combining

# %%
display(df_station_2021)
display(df_station_2022)
# Out:
#             time  station         lon        lat       pm25   i   j
# 0     2018-01-01      201  106.700606  10.783057  31.391304  16  17
# 1     2018-01-02      201  106.700606  10.783057  37.458333  16  17
# 2     2018-01-03      201  106.700606  10.783057  68.083333  16  17
# 3     2018-01-04      201  106.700606  10.783057  51.260870  16  17
# 4     2018-01-05      201  106.700606  10.783057  18.909091  16  17
# ...          ...      ...         ...        ...        ...  ..  ..
# 11683 2021-12-27      216  106.659300  10.780630  35.099753  16  16
# 11684 2021-12-28      216  106.659300  10.780630  24.782436  16  16
# 11685 2021-12-29      216  106.659300  10.780630  25.165238  16  16
# 11686 2021-12-30      216  106.659300  10.780630  16.656319  16  16
# 11687 2021-12-31      216  106.659300  10.780630  19.637165  16  16
#
# [11688 rows x 7 columns]
#            time  station        lat         lon       pm25     i     j
# 0    2022-01-01      201  10.783456  106.700622  21.695652  16.0  17.0
# 1    2022-01-02      201  10.783456  106.700622  24.583333  16.0  17.0
# 2    2022-01-03      201  10.783456  106.700622  31.083333  16.0  17.0
# 3    2022-01-04      201  10.783456  106.700622  50.916667  16.0  17.0
# 4    2022-01-05      201  10.783456  106.700622  33.041667  16.0  17.0
# ...         ...      ...        ...         ...        ...   ...   ...
# 1455 2022-12-27      216  10.780482  106.659511  39.659816  16.0  16.0
# 1456 2022-12-28      216  10.780482  106.659511  44.679352  16.0  16.0
# 1457 2022-12-29      216  10.780482  106.659511  30.724708  16.0  16.0
# 1458 2022-12-30      216  10.780482  106.659511  33.091428  16.0  16.0
# 1459 2022-12-31      216  10.780482  106.659511  28.854069  16.0  16.0
#
# [1460 rows x 7 columns]

# %%
# Merge 2 station table
df_station = pd.concat([df_station_2021, df_station_2022])

# Sort by station then time
df_station.sort_values(by=["station", "time"], inplace=True, ignore_index=True)

# Store file for debugging
df_station.to_csv("df_station.csv", index=False)

df_station
# Out:
#             time  station         lon        lat       pm25     i     j
# 0     2018-01-01      201  106.700606  10.783057  31.391304  16.0  17.0
# 1     2018-01-02      201  106.700606  10.783057  37.458333  16.0  17.0
# 2     2018-01-03      201  106.700606  10.783057  68.083333  16.0  17.0
# 3     2018-01-04      201  106.700606  10.783057  51.260870  16.0  17.0
# 4     2018-01-05      201  106.700606  10.783057  18.909091  16.0  17.0
# ...          ...      ...         ...        ...        ...   ...   ...
# 13143 2022-12-27      216  106.659511  10.780482  39.659816  16.0  16.0
# 13144 2022-12-28      216  106.659511  10.780482  44.679352  16.0  16.0
# 13145 2022-12-29      216  106.659511  10.780482  30.724708  16.0  16.0
# 13146 2022-12-30      216  106.659511  10.780482  33.091428  16.0  16.0
# 13147 2022-12-31      216  106.659511  10.780482  28.854069  16.0  16.0
#
# [13148 rows x 7 columns]

# %% [markdown]
# ## Check null

# %%
df_station.isnull().sum()
# Out:
# time          0
# station       0
# lon           0
# lat           0
# pm25       9256
# i             0
# j             0
# dtype: int64

# %% [markdown]
# ## Get the final station-location map

# %%
{station: (i, j) for station, i, j in list(df_station.loc[:, ["station", "i", "j"]].drop_duplicates().itertuples(index=False, name=None))}
# Out:
# {201: (16.0, 17.0),
#  202: (17.0, 17.0),
#  211: (12.0, 22.0),
#  212: (18.0, 14.0),
#  213: (15.0, 14.0),
#  214: (15.0, 18.0),
#  215: (17.0, 17.0),
#  216: (16.0, 16.0)}

# %% [markdown]
# # Merge MPair data with station data (inner join)

# %% [markdown]
# ## Start merging

# %%
df_mpair = df_mpair_raw.merge(df_station, how="inner", on=["time", "i", "j"])
df_mpair
# Out:
#         i   j      lat_x       lon_x       time   pm25_3km        tmp  \
# 0      12  22  10.879919  106.803950 2018-01-01  28.327724  25.411108
# 1      15  14  10.812461  106.620857 2018-01-01  32.503841  25.192156
# 2      15  18  10.812461  106.712403 2018-01-01  32.679893  25.364946
# 3      16  16  10.789976  106.666630 2018-01-01  35.773865  25.153463
# 4      16  17  10.789976  106.689516 2018-01-01  35.139252  25.189195
# ...    ..  ..        ...         ...        ...        ...        ...
# 13143  17  17  10.767490  106.689516 2022-12-30  19.083696  25.032667
# 13144  15  18  10.812461  106.712403 2022-12-31  28.247709  26.630608
# 13145  16  16  10.789976  106.666630 2022-12-31  27.739468  25.420719
# 13146  16  17  10.789976  106.689516 2022-12-31  26.935106  25.481535
# 13147  17  17  10.767490  106.689516 2022-12-31  26.584717  25.428596
#
#               rh        hpbl      wspd  ...      cropland      grassland  \
# 0      64.382072    2.048351  2.048351  ...  20562.897823  151361.367404
# 1      67.822024    2.399678  2.399678  ...  20717.659283   58947.442429
# 2      67.061844    2.368901  2.368901  ...   6083.319648   17783.771810
# 3      70.151612    2.407680  2.407680  ...     28.761909    7179.267694
# 4      69.899919    2.384306  2.384306  ...      9.037443    1221.246398
# ...          ...         ...       ...  ...           ...            ...
# 13143  64.868401  669.416260  3.893373  ...    229.889184    2906.313289
# 13144  55.478946  607.372803  4.216505  ...   6083.319648   17783.771810
# 13145  59.543566  783.973083  4.161581  ...     28.761909    7179.267694
# 13146  59.598768  778.749390  4.166253  ...      9.037443    1221.246398
# 13147  62.377899  793.388794  4.161542  ...    229.889184    2906.313289
#
#            treecover          water         ndvi          aod  station  \
# 0      282947.325347   39120.320073          NaN     2.078775      211
# 1      108246.100356     492.146554  2580.669322     1.623596      213
# 2       95404.824438  127492.687793  2042.834978 -9999.000000      214
# 3       48393.446780   12262.365566  1686.406661 -9999.000000      216
# 4       86858.898791   32195.290892  1830.941629 -9999.000000      201
# ...              ...            ...          ...          ...      ...
# 13143   68310.042059   46929.703983  1876.516122 -9999.000000      215
# 13144   95404.824438  127492.687793  2042.834978 -9999.000000      214
# 13145   48393.446780   12262.365566  1686.406661 -9999.000000      216
# 13146   86858.898791   32195.290892  1830.941629 -9999.000000      201
# 13147   68310.042059   46929.703983  1876.516122 -9999.000000      215
#
#             lon_y      lat_y       pm25
# 0      106.796200  10.870190        NaN
# 1      106.620500  10.816350        NaN
# 2      106.717500  10.815570        NaN
# 3      106.659300  10.780630        NaN
# 4      106.700606  10.783057  31.391304
# ...           ...        ...        ...
# 13143  106.687955  10.776415        NaN
# 13144  106.717396  10.815839  27.879261
# 13145  106.659511  10.780482  28.854069
# 13146  106.700622  10.783456  33.958333
# 13147  106.687955  10.776415        NaN
#
# [13148 rows x 26 columns]

# %%
df_mpair.isnull().sum()
# Out:
# i                       0
# j                       0
# lat_x                   0
# lon_x                   0
# time                    0
# pm25_3km                0
# tmp                     0
# rh                      0
# hpbl                    0
# wspd                    0
# pop                     0
# road_den_1km            0
# prim_road_len_1km    8035
# near_dist               0
# bareland                0
# builtup                 0
# cropland                0
# grassland               0
# treecover               0
# water                   0
# ndvi                 1461
# aod                     8
# station                 0
# lon_y                   0
# lat_y                   0
# pm25                 9256
# dtype: int64

# %% [markdown]
# ## Handle metadata

# %%
# Drop redundant columns
df_mpair.drop(columns=["lat_y", "lon_y"], axis=1, inplace=True)

# Rename "lat_x" to "lat", "lon_x" to "lon"
df_mpair.rename(columns={"lat_x": "lat", "lon_x": "lon"}, inplace=True)

# Sort data by "station" then "time"
df_mpair.sort_values(by=["station", "time"], inplace=True)

df_mpair
# Out:
#         i   j        lat         lon       time   pm25_3km        tmp  \
# 4      16  17  10.789976  106.689516 2018-01-01  35.139252  25.189195
# 12     16  17  10.789976  106.689516 2018-01-02  52.154430  24.712185
# 20     16  17  10.789976  106.689516 2018-01-03  38.429718  26.079463
# 28     16  17  10.789976  106.689516 2018-01-04  40.447906  26.507970
# 36     16  17  10.789976  106.689516 2018-01-05  21.827175  25.518272
# ...    ..  ..        ...         ...        ...        ...        ...
# 13129  16  16  10.789976  106.666630 2022-12-27  34.151028  24.213715
# 13133  16  16  10.789976  106.666630 2022-12-28  29.592785  25.896009
# 13137  16  16  10.789976  106.666630 2022-12-29  27.141323  25.894251
# 13141  16  16  10.789976  106.666630 2022-12-30  19.889748  25.035917
# 13145  16  16  10.789976  106.666630 2022-12-31  27.739468  25.420719
#
#               rh        hpbl      wspd  ...     bareland        builtup  \
# 4      69.899919    2.384306  2.384306  ...  1056.256477  878404.088663
# 12     73.392725    1.881799  1.881799  ...  1056.256477  878404.088663
# 20     77.673696    1.298009  1.298009  ...  1056.256477  878404.088663
# 28     82.940283  458.829569  1.601857  ...  1056.256477  878404.088663
# 36     93.031988  336.472309  2.548349  ...  1056.256477  878404.088663
# ...          ...         ...       ...  ...          ...            ...
# 13129  69.134701  463.417114  2.020892  ...  2272.289336  929982.248561
# 13133  62.308920  647.989014  2.376687  ...  2272.289336  929982.248561
# 13137  63.947048  813.575928  2.991689  ...  2272.289336  929982.248561
# 13141  61.037365  668.597046  4.194347  ...  2272.289336  929982.248561
# 13145  59.543566  783.973083  4.161581  ...  2272.289336  929982.248561
#
#         cropland    grassland     treecover         water         ndvi  \
# 4       9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 12      9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 20      9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 28      9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 36      9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# ...          ...          ...           ...           ...          ...
# 13129  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 13133  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 13137  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 13141  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 13145  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
#
#                aod  station       pm25
# 4     -9999.000000      201  31.391304
# 12        0.914681      201  37.458333
# 20        1.071576      201  68.083333
# 28        0.648341      201  51.260870
# 36    -9999.000000      201  18.909091
# ...            ...      ...        ...
# 13129 -9999.000000      216  39.659816
# 13133 -9999.000000      216  44.679352
# 13137     0.193722      216  30.724708
# 13141 -9999.000000      216  33.091428
# 13145 -9999.000000      216  28.854069
#
# [13148 rows x 24 columns]

# %%
df_mpair.isnull().sum()
# Out:
# i                       0
# j                       0
# lat                     0
# lon                     0
# time                    0
# pm25_3km                0
# tmp                     0
# rh                      0
# hpbl                    0
# wspd                    0
# pop                     0
# road_den_1km            0
# prim_road_len_1km    8035
# near_dist               0
# bareland                0
# builtup                 0
# cropland                0
# grassland               0
# treecover               0
# water                   0
# ndvi                 1461
# aod                     8
# station                 0
# pm25                 9256
# dtype: int64

# %% [markdown]
# ## Export data

# %%
df_mpair.to_csv(conf["dataset"]["mpair"]["merged_data_dir"], index=False)

# %% [markdown]
# # Merge MPair data with station data, keep all locations

# %% [markdown]
# ## Filter out the invalid location

# %%
df_mpair_raw
# Out:
#           i   j        lat         lon       time     pm25_3km          tmp  \
# 0         0   0  11.149747  106.300443 2018-01-01 -9999.000000 -9999.000000
# 1         0   1  11.149747  106.323330 2018-01-01 -9999.000000 -9999.000000
# 2         0   2  11.149747  106.346217 2018-01-01 -9999.000000 -9999.000000
# 3         0   3  11.149747  106.369103 2018-01-01    24.740000    25.460614
# 4         0   4  11.149747  106.391990 2018-01-01    23.760931    25.462688
# ...      ..  ..        ...         ...        ...          ...          ...
# 2236845  34  30  10.385233  106.987043 2022-12-31          NaN    25.815809
# 2236846  34  31  10.385233  107.009930 2022-12-31          NaN    25.815809
# 2236847  34  32  10.385233  107.032816 2022-12-31 -9999.000000    25.601173
# 2236848  34  33  10.385233  107.055703 2022-12-31 -9999.000000    25.560753
# 2236849  34  34  10.385233  107.078590 2022-12-31 -9999.000000    25.834951
#
#                   rh         hpbl         wspd  ...  prim_road_len_1km  \
# 0       -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 1       -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 2       -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 3          65.144661     2.448070     2.448070  ...                NaN
# 4          65.080498     2.438784     2.438784  ...                NaN
# ...              ...          ...          ...  ...                ...
# 2236845    74.737156   207.873199     3.124345  ...                NaN
# 2236846    75.000397   207.873199     3.215876  ...                NaN
# 2236847 -9999.000000   142.227615 -9999.000000  ...                0.0
# 2236848 -9999.000000   129.865280 -9999.000000  ...                0.0
# 2236849 -9999.000000   284.036316 -9999.000000  ...                0.0
#
#              near_dist      bareland       builtup      cropland  \
# 0       -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 1       -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2       -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 3         7.265194e+01  14453.144036  30347.516088  54101.838731
# 4         1.107789e+02   4569.189136  21119.949784  76052.614180
# ...                ...           ...           ...           ...
# 2236845   3.072120e+03  -9999.000000  -9999.000000  -9999.000000
# 2236846   4.355371e+03  -9999.000000  -9999.000000  -9999.000000
# 2236847 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2236848 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2236849 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
#
#              grassland      treecover         water    ndvi          aod
# 0         -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 1         -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 2         -9999.000000   -9999.000000  -9999.000000 -9999.0     0.156327
# 3        203551.710735  683877.574149  13604.234765     NaN     0.167487
# 4        231046.865089  662859.174184   4308.164827     NaN     0.141881
# ...                ...            ...           ...     ...          ...
# 2236845   -9999.000000   -9999.000000  -9999.000000     NaN -9999.000000
# 2236846   -9999.000000   -9999.000000  -9999.000000     NaN -9999.000000
# 2236847   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 2236848   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
# 2236849   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.000000
#
# [2236850 rows x 22 columns]

# %%
# Get the start and end of i, j
mpair_start_i, mpair_end_i = sorted(df_mpair_raw["i"].unique())[0], sorted(df_mpair_raw["i"].unique())[-1]
mpair_start_j, mpair_end_j = sorted(df_mpair_raw["j"].unique())[0], sorted(df_mpair_raw["j"].unique())[-1]
print(mpair_start_i, mpair_end_i, mpair_start_j, mpair_end_j)

# Loop over every location
all_valid_location_dfs = []
for i in range(mpair_start_i, mpair_end_i + 1):
    for j in range(mpair_start_j, mpair_end_j + 1):
        # Get the data for current location
        df_mpair_current_ij = df_mpair_raw.loc[((df_mpair_raw["i"] == i) & (df_mpair_raw["j"] == j))]

        # Replace the invalid value with NaN
        df_mpair_current_ij = df_mpair_current_ij.replace(-9999, np.nan)

        # Filter out values based on pm25_3km
        total_missing = df_mpair_current_ij["pm25_3km"].isnull().sum()
        #missing_threshold = 1000
        missing_threshold = 365 # strictly
        if total_missing >= missing_threshold:
            df_mpair_current_ij.to_csv(os.path.join(conf["workspace"]["data_by_location_dir"], f"df_mpair_current_{i}_{j}_invalid.csv"), index=False)
            print(f"Location: {i}, {j} - missing = {total_missing} => invalid, skipping...")
        else:
            df_mpair_current_ij.to_csv(os.path.join(conf["workspace"]["data_by_location_dir"], f"df_mpair_current_{i}_{j}.csv"), index=False)
            all_valid_location_dfs += [df_mpair_current_ij]

# Combine all valid location data
df_mpair_raw_valid_locations = pd.concat(all_valid_location_dfs, ignore_index=True)
# Out:
# 0 34 0 34
# Location: 0, 0 - missing = 1826 => invalid, skipping...
# Location: 0, 1 - missing = 1826 => invalid, skipping...
# Location: 0, 2 - missing = 1826 => invalid, skipping...
# Location: 0, 32 - missing = 1826 => invalid, skipping...
# Location: 0, 33 - missing = 1826 => invalid, skipping...
# Location: 0, 34 - missing = 1826 => invalid, skipping...
# Location: 1, 0 - missing = 1826 => invalid, skipping...
# Location: 1, 1 - missing = 1826 => invalid, skipping...
# Location: 1, 2 - missing = 1826 => invalid, skipping...
# Location: 1, 32 - missing = 1826 => invalid, skipping...
# Location: 1, 33 - missing = 1826 => invalid, skipping...
# Location: 1, 34 - missing = 1826 => invalid, skipping...
# Location: 2, 0 - missing = 1826 => invalid, skipping...
# Location: 2, 1 - missing = 1826 => invalid, skipping...
# Location: 2, 2 - missing = 1826 => invalid, skipping...
# Location: 2, 32 - missing = 1826 => invalid, skipping...
# Location: 2, 33 - missing = 1826 => invalid, skipping...
# Location: 2, 34 - missing = 1826 => invalid, skipping...
# Location: 3, 0 - missing = 1826 => invalid, skipping...
# Location: 3, 1 - missing = 1826 => invalid, skipping...
# Location: 3, 2 - missing = 1826 => invalid, skipping...
# Location: 3, 32 - missing = 1826 => invalid, skipping...
# Location: 3, 33 - missing = 1826 => invalid, skipping...
# Location: 3, 34 - missing = 1826 => invalid, skipping...
# Location: 4, 0 - missing = 1826 => invalid, skipping...
# Location: 4, 1 - missing = 1826 => invalid, skipping...
# Location: 4, 2 - missing = 1826 => invalid, skipping...
# Location: 4, 32 - missing = 1826 => invalid, skipping...
# Location: 4, 33 - missing = 1826 => invalid, skipping...
# Location: 4, 34 - missing = 1826 => invalid, skipping...
# Location: 5, 0 - missing = 1826 => invalid, skipping...
# Location: 5, 1 - missing = 1826 => invalid, skipping...
# Location: 5, 2 - missing = 1826 => invalid, skipping...
# Location: 5, 32 - missing = 1826 => invalid, skipping...
# Location: 5, 33 - missing = 1826 => invalid, skipping...
# Location: 5, 34 - missing = 1826 => invalid, skipping...
# Location: 6, 0 - missing = 1826 => invalid, skipping...
# Location: 6, 1 - missing = 1826 => invalid, skipping...
# Location: 6, 2 - missing = 1826 => invalid, skipping...
# Location: 6, 32 - missing = 1826 => invalid, skipping...
# Location: 6, 33 - missing = 1826 => invalid, skipping...
# Location: 6, 34 - missing = 1826 => invalid, skipping...
# Location: 7, 0 - missing = 1826 => invalid, skipping...
# Location: 7, 1 - missing = 1826 => invalid, skipping...
# Location: 7, 2 - missing = 1826 => invalid, skipping...
# Location: 7, 32 - missing = 1826 => invalid, skipping...
# Location: 7, 33 - missing = 1826 => invalid, skipping...
# Location: 7, 34 - missing = 1826 => invalid, skipping...
# Location: 8, 0 - missing = 1826 => invalid, skipping...
# Location: 8, 1 - missing = 1826 => invalid, skipping...
# Location: 8, 2 - missing = 1826 => invalid, skipping...
# Location: 8, 32 - missing = 1826 => invalid, skipping...
# Location: 8, 33 - missing = 1826 => invalid, skipping...
# Location: 8, 34 - missing = 1826 => invalid, skipping...
# Location: 9, 0 - missing = 1826 => invalid, skipping...
# Location: 9, 1 - missing = 1826 => invalid, skipping...
# Location: 9, 2 - missing = 1826 => invalid, skipping...
# Location: 9, 32 - missing = 1826 => invalid, skipping...
# Location: 9, 33 - missing = 1826 => invalid, skipping...
# Location: 9, 34 - missing = 1826 => invalid, skipping...
# Location: 10, 0 - missing = 1826 => invalid, skipping...
# Location: 10, 1 - missing = 1826 => invalid, skipping...
# Location: 10, 2 - missing = 1826 => invalid, skipping...
# Location: 10, 32 - missing = 1826 => invalid, skipping...
# Location: 10, 33 - missing = 1826 => invalid, skipping...
# Location: 10, 34 - missing = 1826 => invalid, skipping...
# Location: 11, 0 - missing = 1826 => invalid, skipping...
# Location: 11, 1 - missing = 1826 => invalid, skipping...
# Location: 11, 2 - missing = 1826 => invalid, skipping...
# Location: 11, 32 - missing = 1826 => invalid, skipping...
# Location: 11, 33 - missing = 1826 => invalid, skipping...
# Location: 11, 34 - missing = 1826 => invalid, skipping...
# Location: 12, 0 - missing = 1826 => invalid, skipping...
# Location: 12, 1 - missing = 1826 => invalid, skipping...
# Location: 12, 2 - missing = 1826 => invalid, skipping...
# Location: 12, 32 - missing = 1826 => invalid, skipping...
# Location: 12, 33 - missing = 1826 => invalid, skipping...
# Location: 12, 34 - missing = 1826 => invalid, skipping...
# Location: 13, 0 - missing = 1826 => invalid, skipping...
# Location: 13, 1 - missing = 1826 => invalid, skipping...
# Location: 13, 2 - missing = 1826 => invalid, skipping...
# Location: 13, 32 - missing = 1826 => invalid, skipping...
# Location: 13, 33 - missing = 1826 => invalid, skipping...
# Location: 13, 34 - missing = 1826 => invalid, skipping...
# Location: 14, 0 - missing = 1826 => invalid, skipping...
# Location: 14, 1 - missing = 1826 => invalid, skipping...
# Location: 14, 2 - missing = 1826 => invalid, skipping...
# Location: 14, 32 - missing = 1826 => invalid, skipping...
# Location: 14, 33 - missing = 1826 => invalid, skipping...
# Location: 14, 34 - missing = 1826 => invalid, skipping...
# Location: 15, 0 - missing = 1826 => invalid, skipping...
# Location: 15, 1 - missing = 1826 => invalid, skipping...
# Location: 15, 2 - missing = 1826 => invalid, skipping...
# Location: 15, 32 - missing = 1826 => invalid, skipping...
# Location: 15, 33 - missing = 1826 => invalid, skipping...
# Location: 15, 34 - missing = 1826 => invalid, skipping...
# Location: 16, 0 - missing = 1826 => invalid, skipping...
# Location: 16, 1 - missing = 1826 => invalid, skipping...
# Location: 16, 2 - missing = 1826 => invalid, skipping...
# Location: 16, 32 - missing = 1826 => invalid, skipping...
# Location: 16, 33 - missing = 1826 => invalid, skipping...
# Location: 16, 34 - missing = 1826 => invalid, skipping...
# Location: 17, 0 - missing = 1826 => invalid, skipping...
# Location: 17, 1 - missing = 1826 => invalid, skipping...
# Location: 17, 2 - missing = 1826 => invalid, skipping...
# Location: 17, 32 - missing = 1826 => invalid, skipping...
# Location: 17, 33 - missing = 1826 => invalid, skipping...
# Location: 17, 34 - missing = 1826 => invalid, skipping...
# Location: 18, 0 - missing = 1826 => invalid, skipping...
# Location: 18, 1 - missing = 1826 => invalid, skipping...
# Location: 18, 2 - missing = 1826 => invalid, skipping...
# Location: 18, 32 - missing = 1826 => invalid, skipping...
# Location: 18, 33 - missing = 1826 => invalid, skipping...
# Location: 18, 34 - missing = 1826 => invalid, skipping...
# Location: 19, 0 - missing = 1826 => invalid, skipping...
# Location: 19, 1 - missing = 1826 => invalid, skipping...
# Location: 19, 2 - missing = 1826 => invalid, skipping...
# Location: 19, 32 - missing = 1826 => invalid, skipping...
# Location: 19, 33 - missing = 1826 => invalid, skipping...
# Location: 19, 34 - missing = 1826 => invalid, skipping...
# Location: 20, 0 - missing = 1826 => invalid, skipping...
# Location: 20, 1 - missing = 1826 => invalid, skipping...
# Location: 20, 2 - missing = 1826 => invalid, skipping...
# Location: 20, 32 - missing = 1826 => invalid, skipping...
# Location: 20, 33 - missing = 1826 => invalid, skipping...
# Location: 20, 34 - missing = 1826 => invalid, skipping...
# Location: 21, 0 - missing = 1826 => invalid, skipping...
# Location: 21, 1 - missing = 1826 => invalid, skipping...
# Location: 21, 2 - missing = 1826 => invalid, skipping...
# Location: 21, 32 - missing = 1826 => invalid, skipping...
# Location: 21, 33 - missing = 1826 => invalid, skipping...
# Location: 21, 34 - missing = 1826 => invalid, skipping...
# Location: 22, 0 - missing = 1826 => invalid, skipping...
# Location: 22, 1 - missing = 1826 => invalid, skipping...
# Location: 22, 2 - missing = 1826 => invalid, skipping...
# Location: 22, 32 - missing = 1826 => invalid, skipping...
# Location: 22, 33 - missing = 1826 => invalid, skipping...
# Location: 22, 34 - missing = 1826 => invalid, skipping...
# Location: 23, 0 - missing = 1826 => invalid, skipping...
# Location: 23, 1 - missing = 1826 => invalid, skipping...
# Location: 23, 2 - missing = 1826 => invalid, skipping...
# Location: 23, 31 - missing = 368 => invalid, skipping...
# Location: 23, 32 - missing = 1826 => invalid, skipping...
# Location: 23, 33 - missing = 1826 => invalid, skipping...
# Location: 23, 34 - missing = 1826 => invalid, skipping...
# Location: 24, 0 - missing = 1826 => invalid, skipping...
# Location: 24, 1 - missing = 1826 => invalid, skipping...
# Location: 24, 2 - missing = 1826 => invalid, skipping...
# Location: 24, 31 - missing = 368 => invalid, skipping...
# Location: 24, 32 - missing = 1826 => invalid, skipping...
# Location: 24, 33 - missing = 1826 => invalid, skipping...
# Location: 24, 34 - missing = 1826 => invalid, skipping...
# Location: 25, 0 - missing = 1826 => invalid, skipping...
# Location: 25, 1 - missing = 1826 => invalid, skipping...
# Location: 25, 2 - missing = 1826 => invalid, skipping...
# Location: 25, 29 - missing = 368 => invalid, skipping...
# Location: 25, 30 - missing = 368 => invalid, skipping...
# Location: 25, 31 - missing = 368 => invalid, skipping...
# Location: 25, 32 - missing = 1826 => invalid, skipping...
# Location: 25, 33 - missing = 1826 => invalid, skipping...
# Location: 25, 34 - missing = 1826 => invalid, skipping...
# Location: 26, 0 - missing = 1826 => invalid, skipping...
# Location: 26, 1 - missing = 1826 => invalid, skipping...
# Location: 26, 2 - missing = 1826 => invalid, skipping...
# Location: 26, 29 - missing = 368 => invalid, skipping...
# Location: 26, 30 - missing = 368 => invalid, skipping...
# Location: 26, 31 - missing = 368 => invalid, skipping...
# Location: 26, 32 - missing = 1826 => invalid, skipping...
# Location: 26, 33 - missing = 1826 => invalid, skipping...
# Location: 26, 34 - missing = 1826 => invalid, skipping...
# Location: 27, 0 - missing = 1826 => invalid, skipping...
# Location: 27, 1 - missing = 1826 => invalid, skipping...
# Location: 27, 2 - missing = 1826 => invalid, skipping...
# Location: 27, 32 - missing = 1826 => invalid, skipping...
# Location: 27, 33 - missing = 1826 => invalid, skipping...
# Location: 27, 34 - missing = 1826 => invalid, skipping...
# Location: 28, 0 - missing = 1826 => invalid, skipping...
# Location: 28, 1 - missing = 1826 => invalid, skipping...
# Location: 28, 2 - missing = 1826 => invalid, skipping...
# Location: 28, 32 - missing = 1826 => invalid, skipping...
# Location: 28, 33 - missing = 1826 => invalid, skipping...
# Location: 28, 34 - missing = 1826 => invalid, skipping...
# Location: 29, 0 - missing = 1826 => invalid, skipping...
# Location: 29, 1 - missing = 1826 => invalid, skipping...
# Location: 29, 2 - missing = 1826 => invalid, skipping...
# Location: 29, 31 - missing = 368 => invalid, skipping...
# Location: 29, 32 - missing = 1826 => invalid, skipping...
# Location: 29, 33 - missing = 1826 => invalid, skipping...
# Location: 29, 34 - missing = 1826 => invalid, skipping...
# Location: 30, 0 - missing = 1826 => invalid, skipping...
# Location: 30, 1 - missing = 1826 => invalid, skipping...
# Location: 30, 2 - missing = 1826 => invalid, skipping...
# Location: 30, 28 - missing = 368 => invalid, skipping...
# Location: 30, 29 - missing = 368 => invalid, skipping...
# Location: 30, 30 - missing = 368 => invalid, skipping...
# Location: 30, 31 - missing = 1079 => invalid, skipping...
# Location: 30, 32 - missing = 1826 => invalid, skipping...
# Location: 30, 33 - missing = 1826 => invalid, skipping...
# Location: 30, 34 - missing = 1826 => invalid, skipping...
# Location: 31, 0 - missing = 1826 => invalid, skipping...
# Location: 31, 1 - missing = 1826 => invalid, skipping...
# Location: 31, 2 - missing = 1826 => invalid, skipping...
# Location: 31, 28 - missing = 368 => invalid, skipping...
# Location: 31, 29 - missing = 368 => invalid, skipping...
# Location: 31, 30 - missing = 368 => invalid, skipping...
# Location: 31, 31 - missing = 1079 => invalid, skipping...
# Location: 31, 32 - missing = 1826 => invalid, skipping...
# Location: 31, 33 - missing = 1826 => invalid, skipping...
# Location: 31, 34 - missing = 1826 => invalid, skipping...
# Location: 32, 0 - missing = 1826 => invalid, skipping...
# Location: 32, 1 - missing = 1826 => invalid, skipping...
# Location: 32, 2 - missing = 1826 => invalid, skipping...
# Location: 32, 22 - missing = 368 => invalid, skipping...
# Location: 32, 23 - missing = 368 => invalid, skipping...
# Location: 32, 29 - missing = 368 => invalid, skipping...
# Location: 32, 30 - missing = 368 => invalid, skipping...
# Location: 32, 31 - missing = 400 => invalid, skipping...
# Location: 32, 32 - missing = 1826 => invalid, skipping...
# Location: 32, 33 - missing = 1826 => invalid, skipping...
# Location: 32, 34 - missing = 1826 => invalid, skipping...
# Location: 33, 0 - missing = 1826 => invalid, skipping...
# Location: 33, 1 - missing = 1826 => invalid, skipping...
# Location: 33, 2 - missing = 1826 => invalid, skipping...
# Location: 33, 22 - missing = 368 => invalid, skipping...
# Location: 33, 23 - missing = 368 => invalid, skipping...
# Location: 33, 24 - missing = 368 => invalid, skipping...
# Location: 33, 25 - missing = 368 => invalid, skipping...
# Location: 33, 28 - missing = 368 => invalid, skipping...
# Location: 33, 29 - missing = 368 => invalid, skipping...
# Location: 33, 30 - missing = 368 => invalid, skipping...
# Location: 33, 31 - missing = 400 => invalid, skipping...
# Location: 33, 32 - missing = 1826 => invalid, skipping...
# Location: 33, 33 - missing = 1826 => invalid, skipping...
# Location: 33, 34 - missing = 1826 => invalid, skipping...
# Location: 34, 0 - missing = 1826 => invalid, skipping...
# Location: 34, 1 - missing = 1826 => invalid, skipping...
# Location: 34, 2 - missing = 1826 => invalid, skipping...
# Location: 34, 22 - missing = 368 => invalid, skipping...
# Location: 34, 23 - missing = 1826 => invalid, skipping...
# Location: 34, 24 - missing = 1826 => invalid, skipping...
# Location: 34, 25 - missing = 368 => invalid, skipping...
# Location: 34, 28 - missing = 368 => invalid, skipping...
# Location: 34, 29 - missing = 368 => invalid, skipping...
# Location: 34, 30 - missing = 511 => invalid, skipping...
# Location: 34, 31 - missing = 1826 => invalid, skipping...
# Location: 34, 32 - missing = 1826 => invalid, skipping...
# Location: 34, 33 - missing = 1826 => invalid, skipping...
# Location: 34, 34 - missing = 1826 => invalid, skipping...

# %%
df_mpair_raw_valid_locations
# Out:
#           i   j        lat         lon       time   pm25_3km        tmp  \
# 0         0   3  11.149747  106.369103 2018-01-01  24.740000  25.460614
# 1         0   3  11.149747  106.369103 2018-01-02  34.290001  24.739857
# 2         0   3  11.149747  106.369103 2018-01-03  28.250000  26.696542
# 3         0   3  11.149747  106.369103 2018-01-04  30.870001  27.088334
# 4         0   3  11.149747  106.369103 2018-01-05  15.430000  25.933456
# ...      ..  ..        ...         ...        ...        ...        ...
# 1783997  34  27  10.385233  106.918383 2022-12-27  19.874584  24.644707
# 1783998  34  27  10.385233  106.918383 2022-12-28  17.509365  25.071791
# 1783999  34  27  10.385233  106.918383 2022-12-29  18.428423  25.458431
# 1784000  34  27  10.385233  106.918383 2022-12-30  12.645213  24.636055
# 1784001  34  27  10.385233  106.918383 2022-12-31  16.706522  24.775455
#
#                 rh        hpbl      wspd  ...  prim_road_len_1km   near_dist  \
# 0        65.144661    2.448070  2.448070  ...                NaN   72.651942
# 1        66.633795    1.877883  1.877883  ...                NaN   72.651942
# 2        74.392069    1.809577  1.809577  ...                NaN   72.651942
# 3        76.627008  458.706106  1.855307  ...                NaN   72.651942
# 4        89.905732  378.742727  2.542371  ...                NaN   72.651942
# ...            ...         ...       ...  ...                ...         ...
# 1783997  76.055573  441.420624  2.561953  ...                NaN  365.912235
# 1783998  78.165489  403.261658  2.126233  ...                NaN  365.912235
# 1783999  79.421234  425.696411  1.909332  ...                NaN  365.912235
# 1784000  76.198395  241.369736  2.530340  ...                NaN  365.912235
# 1784001  76.337906  432.667236  2.036375  ...                NaN  365.912235
#
#              bareland       builtup      cropland      grassland  \
# 0        14453.144036  30347.516088  54101.838731  203551.710735
# 1        14453.144036  30347.516088  54101.838731  203551.710735
# 2        14453.144036  30347.516088  54101.838731  203551.710735
# 3        14453.144036  30347.516088  54101.838731  203551.710735
# 4        14453.144036  30347.516088  54101.838731  203551.710735
# ...               ...           ...           ...            ...
# 1783997  24482.287914  48934.328055   8711.125789  154921.372745
# 1783998  24482.287914  48934.328055   8711.125789  154921.372745
# 1783999  24482.287914  48934.328055   8711.125789  154921.372745
# 1784000  24482.287914  48934.328055   8711.125789  154921.372745
# 1784001  24482.287914  48934.328055   8711.125789  154921.372745
#
#              treecover          water  ndvi       aod
# 0        683877.574149   13604.234765   NaN  0.167487
# 1        683877.574149   13604.234765   NaN  0.250706
# 2        683877.574149   13604.234765   NaN  0.137835
# 3        683877.574149   13604.234765   NaN  0.089860
# 4        683877.574149   13604.234765   NaN       NaN
# ...                ...            ...   ...       ...
# 1783997   91390.837123  426893.893429   NaN       NaN
# 1783998   91390.837123  426893.893429   NaN       NaN
# 1783999   91390.837123  426893.893429   NaN  0.174487
# 1784000   91390.837123  426893.893429   NaN       NaN
# 1784001   91390.837123  426893.893429   NaN       NaN
#
# [1784002 rows x 22 columns]

# %%
df_mpair_raw_valid_locations.isnull().sum()
# Out:
# i                          0
# j                          0
# lat                        0
# lon                        0
# time                       0
# pm25_3km                2931
# tmp                     2931
# rh                      2931
# hpbl                    2931
# wspd                    2931
# pop                        0
# road_den_1km               0
# prim_road_len_1km    1773046
# near_dist                  0
# bareland                   0
# builtup                    0
# cropland                   0
# grassland                  0
# treecover                  0
# water                      0
# ndvi                 1391412
# aod                  1004203
# dtype: int64

# %% [markdown]
# ## Start merging

# %%
df_mpair_valid_locations = pd.merge(df_mpair_raw_valid_locations, df_station, how="left", on=["i", "j", "time"])
df_mpair_valid_locations
# Out:
#           i   j      lat_x       lon_x       time   pm25_3km        tmp  \
# 0         0   3  11.149747  106.369103 2018-01-01  24.740000  25.460614
# 1         0   3  11.149747  106.369103 2018-01-02  34.290001  24.739857
# 2         0   3  11.149747  106.369103 2018-01-03  28.250000  26.696542
# 3         0   3  11.149747  106.369103 2018-01-04  30.870001  27.088334
# 4         0   3  11.149747  106.369103 2018-01-05  15.430000  25.933456
# ...      ..  ..        ...         ...        ...        ...        ...
# 1785458  34  27  10.385233  106.918383 2022-12-27  19.874584  24.644707
# 1785459  34  27  10.385233  106.918383 2022-12-28  17.509365  25.071791
# 1785460  34  27  10.385233  106.918383 2022-12-29  18.428423  25.458431
# 1785461  34  27  10.385233  106.918383 2022-12-30  12.645213  24.636055
# 1785462  34  27  10.385233  106.918383 2022-12-31  16.706522  24.775455
#
#                 rh        hpbl      wspd  ...      cropland      grassland  \
# 0        65.144661    2.448070  2.448070  ...  54101.838731  203551.710735
# 1        66.633795    1.877883  1.877883  ...  54101.838731  203551.710735
# 2        74.392069    1.809577  1.809577  ...  54101.838731  203551.710735
# 3        76.627008  458.706106  1.855307  ...  54101.838731  203551.710735
# 4        89.905732  378.742727  2.542371  ...  54101.838731  203551.710735
# ...            ...         ...       ...  ...           ...            ...
# 1785458  76.055573  441.420624  2.561953  ...   8711.125789  154921.372745
# 1785459  78.165489  403.261658  2.126233  ...   8711.125789  154921.372745
# 1785460  79.421234  425.696411  1.909332  ...   8711.125789  154921.372745
# 1785461  76.198395  241.369736  2.530340  ...   8711.125789  154921.372745
# 1785462  76.337906  432.667236  2.036375  ...   8711.125789  154921.372745
#
#              treecover          water  ndvi       aod  station  lon_y  lat_y  \
# 0        683877.574149   13604.234765   NaN  0.167487      NaN    NaN    NaN
# 1        683877.574149   13604.234765   NaN  0.250706      NaN    NaN    NaN
# 2        683877.574149   13604.234765   NaN  0.137835      NaN    NaN    NaN
# 3        683877.574149   13604.234765   NaN  0.089860      NaN    NaN    NaN
# 4        683877.574149   13604.234765   NaN       NaN      NaN    NaN    NaN
# ...                ...            ...   ...       ...      ...    ...    ...
# 1785458   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
# 1785459   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
# 1785460   91390.837123  426893.893429   NaN  0.174487      NaN    NaN    NaN
# 1785461   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
# 1785462   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
#
#          pm25
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1785458   NaN
# 1785459   NaN
# 1785460   NaN
# 1785461   NaN
# 1785462   NaN
#
# [1785463 rows x 26 columns]

# %% [markdown]
# ## Handle metadata

# %%
# Drop redundant columns
df_mpair_valid_locations.drop(columns=["lat_y", "lon_y"], axis=1, inplace=True)

# Rename "lat_x" to "lat", "lon_x" to "lon"
df_mpair_valid_locations.rename(columns={"lat_x": "lat", "lon_x": "lon"}, inplace=True)

# Sort data by location then "time"
df_mpair_valid_locations.sort_values(by=["i", "j", "time"], inplace=True)

df_mpair_valid_locations
# Out:
#           i   j        lat         lon       time   pm25_3km        tmp  \
# 0         0   3  11.149747  106.369103 2018-01-01  24.740000  25.460614
# 1         0   3  11.149747  106.369103 2018-01-02  34.290001  24.739857
# 2         0   3  11.149747  106.369103 2018-01-03  28.250000  26.696542
# 3         0   3  11.149747  106.369103 2018-01-04  30.870001  27.088334
# 4         0   3  11.149747  106.369103 2018-01-05  15.430000  25.933456
# ...      ..  ..        ...         ...        ...        ...        ...
# 1785458  34  27  10.385233  106.918383 2022-12-27  19.874584  24.644707
# 1785459  34  27  10.385233  106.918383 2022-12-28  17.509365  25.071791
# 1785460  34  27  10.385233  106.918383 2022-12-29  18.428423  25.458431
# 1785461  34  27  10.385233  106.918383 2022-12-30  12.645213  24.636055
# 1785462  34  27  10.385233  106.918383 2022-12-31  16.706522  24.775455
#
#                 rh        hpbl      wspd  ...      bareland       builtup  \
# 0        65.144661    2.448070  2.448070  ...  14453.144036  30347.516088
# 1        66.633795    1.877883  1.877883  ...  14453.144036  30347.516088
# 2        74.392069    1.809577  1.809577  ...  14453.144036  30347.516088
# 3        76.627008  458.706106  1.855307  ...  14453.144036  30347.516088
# 4        89.905732  378.742727  2.542371  ...  14453.144036  30347.516088
# ...            ...         ...       ...  ...           ...           ...
# 1785458  76.055573  441.420624  2.561953  ...  24482.287914  48934.328055
# 1785459  78.165489  403.261658  2.126233  ...  24482.287914  48934.328055
# 1785460  79.421234  425.696411  1.909332  ...  24482.287914  48934.328055
# 1785461  76.198395  241.369736  2.530340  ...  24482.287914  48934.328055
# 1785462  76.337906  432.667236  2.036375  ...  24482.287914  48934.328055
#
#              cropland      grassland      treecover          water  ndvi  \
# 0        54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 1        54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 2        54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 3        54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 4        54101.838731  203551.710735  683877.574149   13604.234765   NaN
# ...               ...            ...            ...            ...   ...
# 1785458   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 1785459   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 1785460   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 1785461   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 1785462   8711.125789  154921.372745   91390.837123  426893.893429   NaN
#
#               aod  station  pm25
# 0        0.167487      NaN   NaN
# 1        0.250706      NaN   NaN
# 2        0.137835      NaN   NaN
# 3        0.089860      NaN   NaN
# 4             NaN      NaN   NaN
# ...           ...      ...   ...
# 1785458       NaN      NaN   NaN
# 1785459       NaN      NaN   NaN
# 1785460  0.174487      NaN   NaN
# 1785461       NaN      NaN   NaN
# 1785462       NaN      NaN   NaN
#
# [1785463 rows x 24 columns]

# %% [markdown]
# ## Export data

# %%
df_mpair_valid_locations.to_csv(conf["dataset"]["mpair"]["merged_data_dir_all_locations_2018_2022"], index=False)
