# %% [markdown]
# # Setup

# %%
USE_GPU = True

# %%
import os
import shutil
import sys
import copy

import pandas as pd
import numpy as np

# Append the custom libraries to system path
sys.path.append("/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project")

# Configure device
if not USE_GPU:
    print("Using CPU to train")
    os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
else:
    print("Using GPU to train")

from src.config_reader import ConfigurationReader
from src.data_utils import mice
from src.plot import plot_1_data
# Out:
# Using GPU to train

# %%
conf = ConfigurationReader("/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/model_params.json").data
print(conf)

# Clear all temp folders
def cleanDir(input_dir):
    if os.path.exists(input_dir):
        shutil.rmtree(input_dir)
    os.makedirs(input_dir)

cleanDir(conf["workspace"]["data_by_location_dir"])
# Out:
# {'dataset': {'aod2022': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/MatchingData2022.xlsx', 'target_start_date': '2022-01-01', 'target_end_date': '2022-12-31'}, 'aod2021': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/aod_data_daily.csv', 'target_start_date': '2021-01-01', 'target_end_date': '2021-12-31'}, 'mpair': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/MPair.csv', 'target_start_date': '2021-01-01', 'target_end_date': '2022-12-31', 'station_2022_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/station2022.csv', 'station_2018_2021_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/station2018-2021.csv', 'merged_data_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/mpair_merged.csv', 'merged_data_dir_all_locations': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/mpair_merged_all_locations.csv'}, 'cmaq': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/concentration_station'}, 'pm2022': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/quan-trac/2022'}, 'pm2021': {'file_dir': '/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/quan-trac/2021'}}, 'workspace': {'model_info_dir': '/le_thanh_van_118/workspace/hiep_workspace/model_info', 'model_checkpoints_dir': '/le_thanh_van_118/workspace/hiep_workspace/model_checkpoints', 'data_by_location_dir': '/le_thanh_van_118/workspace/hiep_workspace/data_by_location', 'data_by_station_dir': '/le_thanh_van_118/workspace/hiep_workspace/data_by_station', 'data_statistic_dir': '/le_thanh_van_118/workspace/hiep_workspace/data_statistic', 'best_reduction_models_dir': '/le_thanh_van_118/workspace/hiep_workspace/best_reduction_models', 'best_reduced_data': '/le_thanh_van_118/workspace/hiep_workspace/best_reduced_data'}, 'prediction': {'n_past': 7, 'n_future': 1, 'epochs': 50, 'batch_size': 128}, 'reduction': {'n_past': 7, 'n_future': 7, 'epochs': 50, 'batch_size': 128, 'min_number_of_features': 10}}

# %% [markdown]
# # Load dataset

# %% [markdown]
# ## MPair.csv

# %% [markdown]
# ### Read CSV

# %%
df_mpair_raw = pd.read_csv(conf["dataset"]["mpair"]["file_dir"])
df_mpair_raw
# Out:
#           i   j        lat         lon        time     PM25_3km          TMP  \
# 0         0   0  11.149747  106.300443  2018-01-01 -9999.000000 -9999.000000
# 1         0   1  11.149747  106.323330  2018-01-01 -9999.000000 -9999.000000
# 2         0   2  11.149747  106.346217  2018-01-01 -9999.000000 -9999.000000
# 3         0   3  11.149747  106.369103  2018-01-01    24.740000    25.460614
# 4         0   4  11.149747  106.391990  2018-01-01    23.760931    25.462688
# ...      ..  ..        ...         ...         ...          ...          ...
# 2236845  34  30  10.385233  106.987043  2022-12-31          NaN    25.815809
# 2236846  34  31  10.385233  107.009930  2022-12-31          NaN    25.815809
# 2236847  34  32  10.385233  107.032816  2022-12-31 -9999.000000    25.601173
# 2236848  34  33  10.385233  107.055703  2022-12-31 -9999.000000    25.560753
# 2236849  34  34  10.385233  107.078590  2022-12-31 -9999.000000    25.834951
#
#                   RH         HPBL         WSPD  ...      NEAR_DIST  \
# 0       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 1       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 2       -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 3          65.144661     2.448070     2.448070  ...   7.265194e+01
# 4          65.080498     2.438784     2.438784  ...   1.107789e+02
# ...              ...          ...          ...  ...            ...
# 2236845    74.737156   207.873199     3.124345  ...   3.072120e+03
# 2236846    75.000397   207.873199     3.215876  ...   4.355371e+03
# 2236847 -9999.000000   142.227615 -9999.000000  ... -1.797693e+308
# 2236848 -9999.000000   129.865280 -9999.000000  ... -1.797693e+308
# 2236849 -9999.000000   284.036316 -9999.000000  ... -1.797693e+308
#
#              BARELAND       BUILTUP      CROPLAND      GRASSLAND  \
# 0        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 1        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2        -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 3        14453.144036  30347.516088  54101.838731  203551.710735
# 4         4569.189136  21119.949784  76052.614180  231046.865089
# ...               ...           ...           ...            ...
# 2236845  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236846  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236847  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236848  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2236849  -9999.000000  -9999.000000  -9999.000000   -9999.000000
#
#              TREECOVER         WATER    NDVI          AOD      AIMODEL
# 0         -9999.000000  -9999.000000 -9999.0 -9999.000000 -9999.000000
# 1         -9999.000000  -9999.000000 -9999.0 -9999.000000 -9999.000000
# 2         -9999.000000  -9999.000000 -9999.0     0.156327 -9999.000000
# 3        683877.574149  13604.234765     NaN     0.167487 -9999.000000
# 4        662859.174184   4308.164827     NaN     0.141881 -9999.000000
# ...                ...           ...     ...          ...          ...
# 2236845   -9999.000000  -9999.000000     NaN -9999.000000    14.998473
# 2236846   -9999.000000  -9999.000000     NaN -9999.000000    15.201084
# 2236847   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
# 2236848   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
# 2236849   -9999.000000  -9999.000000 -9999.0 -9999.000000     0.000000
#
# [2236850 rows x 25 columns]

# %%
df_mpair_raw.columns
# Out:
# Index(['i', 'j', 'lat', 'lon', 'time', 'PM25_3km', 'TMP', 'RH', 'HPBL', 'WSPD',
#        'PRES2M', 'POP', 'ROAD_DEN_1km', 'ROAD_LEN_1km', 'PRIM_ROAD_LEN_1km',
#        'NEAR_DIST', 'BARELAND', 'BUILTUP', 'CROPLAND', 'GRASSLAND',
#        'TREECOVER', 'WATER', 'NDVI', 'AOD', 'AIMODEL'],
#       dtype='object')

# %% [markdown]
# ### Handle metadata

# %%
# Convert "time" columns to Pandas datetime
df_mpair_raw = df_mpair_raw.assign(time=pd.to_datetime(df_mpair_raw["time"]))

# Lower case all column names
df_mpair_raw = df_mpair_raw.rename(columns={name: name.lower() for name in df_mpair_raw.columns})

# Get data in 2021 and 2022 only
time_mask = ((df_mpair_raw["time"] >= conf["dataset"]["mpair"]["target_start_date"]) &
             (df_mpair_raw["time"] <= conf["dataset"]["mpair"]["target_end_date"]))
df_mpair_raw = df_mpair_raw.loc[time_mask]
df_mpair_raw.reset_index(inplace=True, drop=True)

# Set "time" column as index
#df_mpair_raw.set_index("time", inplace=True)

# Print
df_mpair_raw
# Out:
#          i   j        lat         lon       time     pm25_3km          tmp  \
# 0        0   0  11.149747  106.300443 2021-01-01 -9999.000000 -9999.000000
# 1        0   1  11.149747  106.323330 2021-01-01 -9999.000000 -9999.000000
# 2        0   2  11.149747  106.346217 2021-01-01 -9999.000000 -9999.000000
# 3        0   3  11.149747  106.369103 2021-01-01    26.040001    25.114687
# 4        0   4  11.149747  106.391990 2021-01-01    25.666174    25.121210
# ...     ..  ..        ...         ...        ...          ...          ...
# 894245  34  30  10.385233  106.987043 2022-12-31          NaN    25.815809
# 894246  34  31  10.385233  107.009930 2022-12-31          NaN    25.815809
# 894247  34  32  10.385233  107.032816 2022-12-31 -9999.000000    25.601173
# 894248  34  33  10.385233  107.055703 2022-12-31 -9999.000000    25.560753
# 894249  34  34  10.385233  107.078590 2022-12-31 -9999.000000    25.834951
#
#                  rh         hpbl         wspd  ...      near_dist  \
# 0      -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 1      -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 2      -9999.000000 -9999.000000 -9999.000000  ... -1.797693e+308
# 3         63.633778   567.478943     4.660580  ...   7.265194e+01
# 4         62.159500   548.132568     5.052152  ...   1.107789e+02
# ...             ...          ...          ...  ...            ...
# 894245    74.737156   207.873199     3.124345  ...   3.072120e+03
# 894246    75.000397   207.873199     3.215876  ...   4.355371e+03
# 894247 -9999.000000   142.227615 -9999.000000  ... -1.797693e+308
# 894248 -9999.000000   129.865280 -9999.000000  ... -1.797693e+308
# 894249 -9999.000000   284.036316 -9999.000000  ... -1.797693e+308
#
#             bareland       builtup      cropland      grassland  \
# 0       -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 1       -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 2       -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 3       14453.144036  30347.516088  54101.838731  203551.710735
# 4        4569.189136  21119.949784  76052.614180  231046.865089
# ...              ...           ...           ...            ...
# 894245  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 894246  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 894247  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 894248  -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 894249  -9999.000000  -9999.000000  -9999.000000   -9999.000000
#
#             treecover         water    ndvi     aod    aimodel
# 0        -9999.000000  -9999.000000 -9999.0 -9999.0   0.000000
# 1        -9999.000000  -9999.000000 -9999.0 -9999.0   0.000000
# 2        -9999.000000  -9999.000000 -9999.0 -9999.0   0.000000
# 3       683877.574149  13604.234765     NaN -9999.0  18.526991
# 4       662859.174184   4308.164827     NaN -9999.0  19.523800
# ...               ...           ...     ...     ...        ...
# 894245   -9999.000000  -9999.000000     NaN -9999.0  14.998473
# 894246   -9999.000000  -9999.000000     NaN -9999.0  15.201084
# 894247   -9999.000000  -9999.000000 -9999.0 -9999.0   0.000000
# 894248   -9999.000000  -9999.000000 -9999.0 -9999.0   0.000000
# 894249   -9999.000000  -9999.000000 -9999.0 -9999.0   0.000000
#
# [894250 rows x 25 columns]

# %% [markdown]
# ### Drop unnecessary columns

# %%
# Drop the columns because they are not in the matching data 2021 2022
# Use "python set" to check if the columns to drop are actually in the dataset
columns_to_drop = set(["aimodel", "pres2m", "road_len_1km"]) & set(df_mpair_raw.columns)
print(columns_to_drop)
df_mpair_raw = df_mpair_raw.drop(columns=columns_to_drop)
df_mpair_raw
# Out:
# {'pres2m', 'aimodel', 'road_len_1km'}
#          i   j        lat         lon       time     pm25_3km          tmp  \
# 0        0   0  11.149747  106.300443 2021-01-01 -9999.000000 -9999.000000
# 1        0   1  11.149747  106.323330 2021-01-01 -9999.000000 -9999.000000
# 2        0   2  11.149747  106.346217 2021-01-01 -9999.000000 -9999.000000
# 3        0   3  11.149747  106.369103 2021-01-01    26.040001    25.114687
# 4        0   4  11.149747  106.391990 2021-01-01    25.666174    25.121210
# ...     ..  ..        ...         ...        ...          ...          ...
# 894245  34  30  10.385233  106.987043 2022-12-31          NaN    25.815809
# 894246  34  31  10.385233  107.009930 2022-12-31          NaN    25.815809
# 894247  34  32  10.385233  107.032816 2022-12-31 -9999.000000    25.601173
# 894248  34  33  10.385233  107.055703 2022-12-31 -9999.000000    25.560753
# 894249  34  34  10.385233  107.078590 2022-12-31 -9999.000000    25.834951
#
#                  rh         hpbl         wspd  ...  prim_road_len_1km  \
# 0      -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 1      -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 2      -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 3         63.633778   567.478943     4.660580  ...                NaN
# 4         62.159500   548.132568     5.052152  ...                NaN
# ...             ...          ...          ...  ...                ...
# 894245    74.737156   207.873199     3.124345  ...                NaN
# 894246    75.000397   207.873199     3.215876  ...                NaN
# 894247 -9999.000000   142.227615 -9999.000000  ...                0.0
# 894248 -9999.000000   129.865280 -9999.000000  ...                0.0
# 894249 -9999.000000   284.036316 -9999.000000  ...                0.0
#
#             near_dist      bareland       builtup      cropland  \
# 0      -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 1      -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2      -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 3        7.265194e+01  14453.144036  30347.516088  54101.838731
# 4        1.107789e+02   4569.189136  21119.949784  76052.614180
# ...               ...           ...           ...           ...
# 894245   3.072120e+03  -9999.000000  -9999.000000  -9999.000000
# 894246   4.355371e+03  -9999.000000  -9999.000000  -9999.000000
# 894247 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 894248 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 894249 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
#
#             grassland      treecover         water    ndvi     aod
# 0        -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 1        -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 2        -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 3       203551.710735  683877.574149  13604.234765     NaN -9999.0
# 4       231046.865089  662859.174184   4308.164827     NaN -9999.0
# ...               ...            ...           ...     ...     ...
# 894245   -9999.000000   -9999.000000  -9999.000000     NaN -9999.0
# 894246   -9999.000000   -9999.000000  -9999.000000     NaN -9999.0
# 894247   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 894248   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 894249   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
#
# [894250 rows x 22 columns]

# %% [markdown]
# ## station2018-2021.csv

# %% [markdown]
# ### Read CSV

# %%
df_station_2021 = pd.read_csv(conf["dataset"]["mpair"]["station_2018_2021_dir"])
df_station_2021
# Out:
#                   time   ID         Lon        Lat       pm25   i   j
# 0        1/1/2018 0:00  201  106.700606  10.783057  31.391304  16  17
# 1        1/1/2018 0:00  202  106.682027  10.762638  29.615625  17  17
# 2        1/1/2018 0:00  211  106.796200  10.870190        NaN  12  22
# 3        1/1/2018 0:00  212  106.617000  10.740760        NaN  18  14
# 4        1/1/2018 0:00  213  106.620500  10.816350        NaN  15  14
# ...                ...  ...         ...        ...        ...  ..  ..
# 11683  12/31/2021 0:00  212  106.617000  10.740760  20.100752  18  14
# 11684  12/31/2021 0:00  213  106.620500  10.816350  23.240539  15  14
# 11685  12/31/2021 0:00  214  106.717500  10.815570  20.549839  15  18
# 11686  12/31/2021 0:00  215  106.687900  10.776280        NaN  17  17
# 11687  12/31/2021 0:00  216  106.659300  10.780630  19.637165  16  16
#
# [11688 rows x 7 columns]

# %% [markdown]
# ### Handle metadata

# %%
# Convert "time" columns to Pandas datetime
df_station_2021 = df_station_2021.assign(time=pd.to_datetime(df_station_2021["time"]))

# Lower case all column names
df_station_2021 = df_station_2021.rename(columns={name: name.lower() for name in df_station_2021.columns})

# Rename "id" column to "station"
df_station_2021 = df_station_2021.rename(columns={"id": "station"})

# Get data in 2021 only
time_mask = ((df_station_2021["time"] >= conf["dataset"]["aod2021"]["target_start_date"]) & 
             (df_station_2021["time"] <= conf["dataset"]["aod2021"]["target_end_date"]))
df_station_2021 = df_station_2021.loc[time_mask]

# Sort data by station then time
df_station_2021.sort_values(by=["station", "time"], inplace=True, ignore_index=True)

# Print
df_station_2021
# Out:
#            time  station         lon        lat       pm25   i   j
# 0    2021-01-01      201  106.700606  10.783057  17.250000  16  17
# 1    2021-01-02      201  106.700606  10.783057  23.000000  16  17
# 2    2021-01-03      201  106.700606  10.783057  28.291667  16  17
# 3    2021-01-04      201  106.700606  10.783057  28.791667  16  17
# 4    2021-01-05      201  106.700606  10.783057  24.833333  16  17
# ...         ...      ...         ...        ...        ...  ..  ..
# 2915 2021-12-27      216  106.659300  10.780630  35.099753  16  16
# 2916 2021-12-28      216  106.659300  10.780630  24.782436  16  16
# 2917 2021-12-29      216  106.659300  10.780630  25.165238  16  16
# 2918 2021-12-30      216  106.659300  10.780630  16.656319  16  16
# 2919 2021-12-31      216  106.659300  10.780630  19.637165  16  16
#
# [2920 rows x 7 columns]

# %% [markdown]
# ### Check null

# %%
df_station_2021.isnull().sum()
# Out:
# time          0
# station       0
# lon           0
# lat           0
# pm25       1345
# i             0
# j             0
# dtype: int64

# %%
for station in df_station_2021["station"].unique():
    df_current_station = df_station_2021[df_station_2021["station"] == station]
    display(df_current_station.isnull().sum())
# Out:
# time        0
# station     0
# lon         0
# lat         0
# pm25       16
# i           0
# j           0
# dtype: int64
# time         0
# station      0
# lon          0
# lat          0
# pm25       365
# i            0
# j            0
# dtype: int64
# time         0
# station      0
# lon          0
# lat          0
# pm25       192
# i            0
# j            0
# dtype: int64
# time         0
# station      0
# lon          0
# lat          0
# pm25       116
# i            0
# j            0
# dtype: int64
# time         0
# station      0
# lon          0
# lat          0
# pm25       139
# i            0
# j            0
# dtype: int64
# time         0
# station      0
# lon          0
# lat          0
# pm25       105
# i            0
# j            0
# dtype: int64
# time         0
# station      0
# lon          0
# lat          0
# pm25       260
# i            0
# j            0
# dtype: int64
# time         0
# station      0
# lon          0
# lat          0
# pm25       152
# i            0
# j            0
# dtype: int64

# %%
'''
all_valid_stations_2021_dfs = []
for station in df_station_2021["station"].unique():
    df_current_station = df_station_2021.loc[df_station_2021["station"] == station]

    # Fill missing pm25
    #mean_pm25_current_station = df_current_station["pm25"].mean()
    #if mean_pm25_current_station >= 0:
    #    df_current_station.loc[:, "pm25"] = df_current_station["pm25"].fillna(value=df_current_station["pm25"].mean())
    #    all_valid_stations_2021_dfs.append(df_current_station)
    #print(f"station = {station}, mean_pm25 = {mean_pm25_current_station}")

# Combine all data
df_station_2021 = pd.concat(all_valid_stations_2021_dfs).reset_index()
df_station_2021
'''
# Out:
# '\nall_valid_stations_2021_dfs = []\nfor station in df_station_2021["station"].unique():\n    df_current_station = df_station_2021.loc[df_station_2021["station"] == station]\n\n    # Fill missing pm25\n    #mean_pm25_current_station = df_current_station["pm25"].mean()\n    #if mean_pm25_current_station >= 0:\n    #    df_current_station.loc[:, "pm25"] = df_current_station["pm25"].fillna(value=df_current_station["pm25"].mean())\n    #    all_valid_stations_2021_dfs.append(df_current_station)\n    #print(f"station = {station}, mean_pm25 = {mean_pm25_current_station}")\n\n# Combine all data\ndf_station_2021 = pd.concat(all_valid_stations_2021_dfs).reset_index()\ndf_station_2021\n'

# %% [markdown]
# ### Filter out the invalid stations

# %%
# Filter out the invalid station
all_valid_dfs = []
for station in df_station_2021["station"].unique():
    df_current_station = df_station_2021.loc[df_station_2021["station"] == station]
    number_of_missing_values = df_current_station["pm25"].isnull().sum()
    if number_of_missing_values >= 365:
        print(f"station {station} have {df_current_station['pm25'].isnull().sum()} missing values, skipping")
    else:
        print(f"station {station} have {df_current_station['pm25'].isnull().sum()} missing values")
        all_valid_dfs.append(df_current_station)
df_station_2021 = pd.concat(all_valid_dfs)
df_station_2021
# Out:
# station 201 have 16 missing values
# station 202 have 365 missing values, skipping
# station 211 have 192 missing values
# station 212 have 116 missing values
# station 213 have 139 missing values
# station 214 have 105 missing values
# station 215 have 260 missing values
# station 216 have 152 missing values
#            time  station         lon        lat       pm25   i   j
# 0    2021-01-01      201  106.700606  10.783057  17.250000  16  17
# 1    2021-01-02      201  106.700606  10.783057  23.000000  16  17
# 2    2021-01-03      201  106.700606  10.783057  28.291667  16  17
# 3    2021-01-04      201  106.700606  10.783057  28.791667  16  17
# 4    2021-01-05      201  106.700606  10.783057  24.833333  16  17
# ...         ...      ...         ...        ...        ...  ..  ..
# 2915 2021-12-27      216  106.659300  10.780630  35.099753  16  16
# 2916 2021-12-28      216  106.659300  10.780630  24.782436  16  16
# 2917 2021-12-29      216  106.659300  10.780630  25.165238  16  16
# 2918 2021-12-30      216  106.659300  10.780630  16.656319  16  16
# 2919 2021-12-31      216  106.659300  10.780630  19.637165  16  16
#
# [2555 rows x 7 columns]

# %% [markdown]
# ### Get the location-station map

# %%
# Get the location i, j of each station
all_stations = [int(ele) for ele in df_station_2021["station"].unique()]
station_ij_map_2021 = {}
for station in all_stations:
    i = int(df_station_2021.loc[df_station_2021["station"] == station]["i"].unique()[0])
    j = int(df_station_2021.loc[df_station_2021["station"] == station]["j"].unique()[0])
    station_ij_map_2021[station] = (i, j)
station_ij_map_2021
# Out:
# {201: (16, 17),
#  211: (12, 22),
#  212: (18, 14),
#  213: (15, 14),
#  214: (15, 18),
#  215: (17, 17),
#  216: (16, 16)}

# %% [markdown]
# ## station2022.csv

# %% [markdown]
# ### Read CSV

# %%
df_station_2022 = pd.read_csv(conf["dataset"]["mpair"]["station_2022_dir"])
df_station_2022
# Out:
#            time  ID        lat         lon       pm25   i   j
# 0    2022-01-01  S4  10.815839  106.717396  23.768238  15  18
# 1    2022-01-01  S5  10.776415  106.687955  14.221014  17  17
# 2    2022-01-01  S6  10.780482  106.659511  21.405015  16  16
# 3    2022-01-01  S7  10.783456  106.700622  21.695652  16  17
# 4    2022-01-02  S4  10.815839  106.717396  22.154723  15  18
# ..          ...  ..        ...         ...        ...  ..  ..
# 993  2022-12-30  S6  10.780482  106.659511  33.091428  16  16
# 994  2022-12-30  S7  10.783456  106.700622  40.166667  16  17
# 995  2022-12-31  S4  10.815839  106.717396  27.879261  15  18
# 996  2022-12-31  S6  10.780482  106.659511  28.854069  16  16
# 997  2022-12-31  S7  10.783456  106.700622  33.958333  16  17
#
# [998 rows x 7 columns]

# %% [markdown]
# ### Handle metadata

# %%
# Convert "time" columns to Pandas datetime
df_station_2022 = df_station_2022.assign(time=pd.to_datetime(df_station_2022["time"]))

# Lower case all column names
df_station_2022 = df_station_2022.rename(columns={name: name.lower() for name in df_station_2022.columns})

# Rename "id" column to "station"
df_station_2022 = df_station_2022.rename(columns={"id": "station"})

# Print
df_station_2022
# Out:
#           time station        lat         lon       pm25   i   j
# 0   2022-01-01      S4  10.815839  106.717396  23.768238  15  18
# 1   2022-01-01      S5  10.776415  106.687955  14.221014  17  17
# 2   2022-01-01      S6  10.780482  106.659511  21.405015  16  16
# 3   2022-01-01      S7  10.783456  106.700622  21.695652  16  17
# 4   2022-01-02      S4  10.815839  106.717396  22.154723  15  18
# ..         ...     ...        ...         ...        ...  ..  ..
# 993 2022-12-30      S6  10.780482  106.659511  33.091428  16  16
# 994 2022-12-30      S7  10.783456  106.700622  40.166667  16  17
# 995 2022-12-31      S4  10.815839  106.717396  27.879261  15  18
# 996 2022-12-31      S6  10.780482  106.659511  28.854069  16  16
# 997 2022-12-31      S7  10.783456  106.700622  33.958333  16  17
#
# [998 rows x 7 columns]

# %% [markdown]
# ### Remap the stations to align with 2021 data

# %%
# Get the location i, j of each station
all_stations = df_station_2022["station"].unique()

station_ij_map_2022 = {}
for station in all_stations:
    i = int(df_station_2022.loc[df_station_2022["station"] == station]["i"].unique()[0])
    j = int(df_station_2022.loc[df_station_2022["station"] == station]["j"].unique()[0])
    station_ij_map_2022[station] = (i, j)
print(station_ij_map_2022)

# Generate the replace map
to_replace_station_map = {}
for station_2022, location_2022 in station_ij_map_2022.items():
    for station_2021, location_2021 in station_ij_map_2021.items():
        if location_2021 == location_2022:
            to_replace_station_map[station_2022] = station_2021
print(to_replace_station_map)

# Replace
df_station_2022.loc[:, ["station"]] = df_station_2022["station"].replace(to_replace=to_replace_station_map)

# Sort data by station then time
df_station_2022.sort_values(by=["station", "time"], inplace=True)

df_station_2022
# Out:
# {'S4': (15, 18), 'S5': (17, 17), 'S6': (16, 16), 'S7': (16, 17)}
# {'S4': 214, 'S5': 215, 'S6': 216, 'S7': 201}
# /tmp/ipykernel_1079719/413095497.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_station_2022.loc[:, ["station"]] = df_station_2022["station"].replace(to_replace=to_replace_station_map)
#           time station        lat         lon       pm25   i   j
# 3   2022-01-01     201  10.783456  106.700622  21.695652  16  17
# 7   2022-01-02     201  10.783456  106.700622  24.583333  16  17
# 11  2022-01-03     201  10.783456  106.700622  31.083333  16  17
# 15  2022-01-04     201  10.783456  106.700622  50.916667  16  17
# 19  2022-01-05     201  10.783456  106.700622  33.041667  16  17
# ..         ...     ...        ...         ...        ...  ..  ..
# 984 2022-12-27     216  10.780482  106.659511  39.659816  16  16
# 987 2022-12-28     216  10.780482  106.659511  44.679352  16  16
# 990 2022-12-29     216  10.780482  106.659511  30.724708  16  16
# 993 2022-12-30     216  10.780482  106.659511  33.091428  16  16
# 996 2022-12-31     216  10.780482  106.659511  28.854069  16  16
#
# [998 rows x 7 columns]

# %% [markdown]
# ### Check null

# %%
df_station_2022.isnull().sum()
# Out:
# time       0
# station    0
# lat        0
# lon        0
# pm25       0
# i          0
# j          0
# dtype: int64

# %%
correct_time_stamp = pd.date_range(conf["dataset"]["aod2022"]["target_start_date"], conf["dataset"]["aod2022"]["target_end_date"], freq="D")

all_reindex_dfs = []
# Padding missing data for each station
for station in df_station_2022["station"].unique():
    # Get current station
    df_current_station = df_station_2022.loc[df_station_2022["station"] == station]

    # Set "time" column as index first
    # Then reindex with the correct date range
    # This will fill in the missing timestamp
    df_current_station.set_index("time", inplace=True)
    df_current_station = df_current_station.reindex(correct_time_stamp)

    # Fill the static data
    for feature in ["station", "lat", "lon", "i", "j"]:
        df_current_station[feature] = df_current_station[feature].iloc[0]

    # Fill the pm25
    #df_current_station["pm25"] = df_current_station["pm25"].fillna(df_current_station["pm25"].mean())
    #df_current_station["pm25"] = mice(df_current_station["pm25"])

    # Append data
    print(f"station = {station}, count = {len(df_current_station)}, start_date = {df_current_station.index[0]}, end_date = {df_current_station.index[-1]}")
    all_reindex_dfs.append(df_current_station.reset_index(names="time"))

# Combine all data
df_station_2022 = pd.concat(all_reindex_dfs).reset_index(drop=True)
df_station_2022
# Out:
# station = 201, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
# station = 214, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
# station = 215, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
# station = 216, count = 365, start_date = 2022-01-01 00:00:00, end_date = 2022-12-31 00:00:00
#            time  station        lat         lon       pm25     i     j
# 0    2022-01-01      201  10.783456  106.700622  21.695652  16.0  17.0
# 1    2022-01-02      201  10.783456  106.700622  24.583333  16.0  17.0
# 2    2022-01-03      201  10.783456  106.700622  31.083333  16.0  17.0
# 3    2022-01-04      201  10.783456  106.700622  50.916667  16.0  17.0
# 4    2022-01-05      201  10.783456  106.700622  33.041667  16.0  17.0
# ...         ...      ...        ...         ...        ...   ...   ...
# 1455 2022-12-27      216  10.780482  106.659511  39.659816  16.0  16.0
# 1456 2022-12-28      216  10.780482  106.659511  44.679352  16.0  16.0
# 1457 2022-12-29      216  10.780482  106.659511  30.724708  16.0  16.0
# 1458 2022-12-30      216  10.780482  106.659511  33.091428  16.0  16.0
# 1459 2022-12-31      216  10.780482  106.659511  28.854069  16.0  16.0
#
# [1460 rows x 7 columns]

# %% [markdown]
# # Combine 2 station data

# %% [markdown]
# ## Check stations for each year

# %%
display(df_station_2021["station"].unique())
display(df_station_2022["station"].unique())
# Out:
# array([201, 211, 212, 213, 214, 215, 216])
# array([201, 214, 215, 216])

# %% [markdown]
# ## Start combining

# %%
display(df_station_2021)
display(df_station_2022)
# Out:
#            time  station         lon        lat       pm25   i   j
# 0    2021-01-01      201  106.700606  10.783057  17.250000  16  17
# 1    2021-01-02      201  106.700606  10.783057  23.000000  16  17
# 2    2021-01-03      201  106.700606  10.783057  28.291667  16  17
# 3    2021-01-04      201  106.700606  10.783057  28.791667  16  17
# 4    2021-01-05      201  106.700606  10.783057  24.833333  16  17
# ...         ...      ...         ...        ...        ...  ..  ..
# 2915 2021-12-27      216  106.659300  10.780630  35.099753  16  16
# 2916 2021-12-28      216  106.659300  10.780630  24.782436  16  16
# 2917 2021-12-29      216  106.659300  10.780630  25.165238  16  16
# 2918 2021-12-30      216  106.659300  10.780630  16.656319  16  16
# 2919 2021-12-31      216  106.659300  10.780630  19.637165  16  16
#
# [2555 rows x 7 columns]
#            time  station        lat         lon       pm25     i     j
# 0    2022-01-01      201  10.783456  106.700622  21.695652  16.0  17.0
# 1    2022-01-02      201  10.783456  106.700622  24.583333  16.0  17.0
# 2    2022-01-03      201  10.783456  106.700622  31.083333  16.0  17.0
# 3    2022-01-04      201  10.783456  106.700622  50.916667  16.0  17.0
# 4    2022-01-05      201  10.783456  106.700622  33.041667  16.0  17.0
# ...         ...      ...        ...         ...        ...   ...   ...
# 1455 2022-12-27      216  10.780482  106.659511  39.659816  16.0  16.0
# 1456 2022-12-28      216  10.780482  106.659511  44.679352  16.0  16.0
# 1457 2022-12-29      216  10.780482  106.659511  30.724708  16.0  16.0
# 1458 2022-12-30      216  10.780482  106.659511  33.091428  16.0  16.0
# 1459 2022-12-31      216  10.780482  106.659511  28.854069  16.0  16.0
#
# [1460 rows x 7 columns]

# %%
# Merge 2 station table
df_station = pd.concat([df_station_2021, df_station_2022])

# Sort by station then time
df_station.sort_values(by=["station", "time"], inplace=True, ignore_index=True)

# Store file for debugging
df_station.to_csv("df_station.csv", index=False)

df_station
# Out:
#            time  station         lon        lat       pm25     i     j
# 0    2021-01-01      201  106.700606  10.783057  17.250000  16.0  17.0
# 1    2021-01-02      201  106.700606  10.783057  23.000000  16.0  17.0
# 2    2021-01-03      201  106.700606  10.783057  28.291667  16.0  17.0
# 3    2021-01-04      201  106.700606  10.783057  28.791667  16.0  17.0
# 4    2021-01-05      201  106.700606  10.783057  24.833333  16.0  17.0
# ...         ...      ...         ...        ...        ...   ...   ...
# 4010 2022-12-27      216  106.659511  10.780482  39.659816  16.0  16.0
# 4011 2022-12-28      216  106.659511  10.780482  44.679352  16.0  16.0
# 4012 2022-12-29      216  106.659511  10.780482  30.724708  16.0  16.0
# 4013 2022-12-30      216  106.659511  10.780482  33.091428  16.0  16.0
# 4014 2022-12-31      216  106.659511  10.780482  28.854069  16.0  16.0
#
# [4015 rows x 7 columns]

# %% [markdown]
# ## Check null

# %%
df_station.isnull().sum()
# Out:
# time          0
# station       0
# lon           0
# lat           0
# pm25       1442
# i             0
# j             0
# dtype: int64

# %% [markdown]
# ## Get the final station-location map

# %%
{station: (i, j) for station, i, j in list(df_station.loc[:, ["station", "i", "j"]].drop_duplicates().itertuples(index=False, name=None))}
# Out:
# {201: (16.0, 17.0),
#  211: (12.0, 22.0),
#  212: (18.0, 14.0),
#  213: (15.0, 14.0),
#  214: (15.0, 18.0),
#  215: (17.0, 17.0),
#  216: (16.0, 16.0)}

# %% [markdown]
# # Merge MPair data with station data (inner join)

# %% [markdown]
# ## Start merging

# %%
df_mpair = df_mpair_raw.merge(df_station, how="inner", on=["time", "i", "j"])
df_mpair
# Out:
#        i   j      lat_x       lon_x       time   pm25_3km        tmp  \
# 0     12  22  10.879919  106.803950 2021-01-01  30.366625  25.749989
# 1     15  14  10.812461  106.620857 2021-01-01  36.621094  25.925655
# 2     15  18  10.812461  106.712403 2021-01-01  36.649185  26.025026
# 3     16  16  10.789976  106.666630 2021-01-01  39.352276  25.633114
# 4     16  17  10.789976  106.689516 2021-01-01  38.528156  25.759054
# ...   ..  ..        ...         ...        ...        ...        ...
# 4010  17  17  10.767490  106.689516 2022-12-30  19.083696  25.032667
# 4011  15  18  10.812461  106.712403 2022-12-31  28.247709  26.630608
# 4012  16  16  10.789976  106.666630 2022-12-31  27.739468  25.420719
# 4013  16  17  10.789976  106.689516 2022-12-31  26.935106  25.481535
# 4014  17  17  10.767490  106.689516 2022-12-31  26.584717  25.428596
#
#              rh        hpbl      wspd  ...      cropland      grassland  \
# 0     61.403439  533.919250  3.311250  ...  20562.897823  151361.367404
# 1     58.359192  536.831421  4.195177  ...  20717.659283   58947.442429
# 2     59.134865  579.871704  3.491554  ...   6083.319648   17783.771810
# 3     61.730026  479.575165  4.054595  ...     28.761909    7179.267694
# 4     61.073494  520.164246  3.809916  ...      9.037443    1221.246398
# ...         ...         ...       ...  ...           ...            ...
# 4010  64.868401  669.416260  3.893373  ...    229.889184    2906.313289
# 4011  55.478946  607.372803  4.216505  ...   6083.319648   17783.771810
# 4012  59.543566  783.973083  4.161581  ...     28.761909    7179.267694
# 4013  59.598768  778.749390  4.166253  ...      9.037443    1221.246398
# 4014  62.377899  793.388794  4.161542  ...    229.889184    2906.313289
#
#           treecover          water         ndvi     aod  station       lon_y  \
# 0     282947.325347   39120.320073          NaN -9999.0      211  106.796200
# 1     108246.100356     492.146554  2580.669322 -9999.0      213  106.620500
# 2      95404.824438  127492.687793  2042.834978 -9999.0      214  106.717500
# 3      48393.446780   12262.365566  1686.406661 -9999.0      216  106.659300
# 4      86858.898791   32195.290892  1830.941629 -9999.0      201  106.700606
# ...             ...            ...          ...     ...      ...         ...
# 4010   68310.042059   46929.703983  1876.516122 -9999.0      215  106.687955
# 4011   95404.824438  127492.687793  2042.834978 -9999.0      214  106.717396
# 4012   48393.446780   12262.365566  1686.406661 -9999.0      216  106.659511
# 4013   86858.898791   32195.290892  1830.941629 -9999.0      201  106.700622
# 4014   68310.042059   46929.703983  1876.516122 -9999.0      215  106.687955
#
#           lat_y       pm25
# 0     10.870190        NaN
# 1     10.816350        NaN
# 2     10.815570        NaN
# 3     10.780630        NaN
# 4     10.783057  17.250000
# ...         ...        ...
# 4010  10.776415        NaN
# 4011  10.815839  27.879261
# 4012  10.780482  28.854069
# 4013  10.783456  33.958333
# 4014  10.776415        NaN
#
# [4015 rows x 26 columns]

# %%
df_mpair.isnull().sum()
# Out:
# i                       0
# j                       0
# lat_x                   0
# lon_x                   0
# time                    0
# pm25_3km                0
# tmp                     0
# rh                      0
# hpbl                    0
# wspd                    0
# pop                     0
# road_den_1km            0
# prim_road_len_1km    2555
# near_dist               0
# bareland                0
# builtup                 0
# cropland                0
# grassland               0
# treecover               0
# water                   0
# ndvi                  365
# aod                     7
# station                 0
# lon_y                   0
# lat_y                   0
# pm25                 1442
# dtype: int64

# %% [markdown]
# ## Handle metadata

# %%
# Drop redundant columns
df_mpair.drop(columns=["lat_y", "lon_y"], axis=1, inplace=True)

# Rename "lat_x" to "lat", "lon_x" to "lon"
df_mpair.rename(columns={"lat_x": "lat", "lon_x": "lon"}, inplace=True)

# Sort data by "station" then "time"
df_mpair.sort_values(by=["station", "time"], inplace=True)

df_mpair
# Out:
#        i   j        lat         lon       time   pm25_3km        tmp  \
# 4     16  17  10.789976  106.689516 2021-01-01  38.528156  25.759054
# 11    16  17  10.789976  106.689516 2021-01-02  57.013439  25.378061
# 18    16  17  10.789976  106.689516 2021-01-03  57.202629  26.691256
# 25    16  17  10.789976  106.689516 2021-01-04  61.890816  27.549019
# 32    16  17  10.789976  106.689516 2021-01-05  70.329758  27.360172
# ...   ..  ..        ...         ...        ...        ...        ...
# 3996  16  16  10.789976  106.666630 2022-12-27  34.151028  24.213715
# 4000  16  16  10.789976  106.666630 2022-12-28  29.592785  25.896009
# 4004  16  16  10.789976  106.666630 2022-12-29  27.141323  25.894251
# 4008  16  16  10.789976  106.666630 2022-12-30  19.889748  25.035917
# 4012  16  16  10.789976  106.666630 2022-12-31  27.739468  25.420719
#
#              rh        hpbl      wspd  ...     bareland        builtup  \
# 4     61.073494  520.164246  3.809916  ...  1056.256477  878404.088663
# 11    61.142441  524.404724  2.527972  ...  1056.256477  878404.088663
# 18    62.528309  467.049805  1.928542  ...  1056.256477  878404.088663
# 25    62.431583  600.658997  1.653818  ...  1056.256477  878404.088663
# 32    63.041634  654.842773  2.941231  ...  1056.256477  878404.088663
# ...         ...         ...       ...  ...          ...            ...
# 3996  69.134701  463.417114  2.020892  ...  2272.289336  929982.248561
# 4000  62.308920  647.989014  2.376687  ...  2272.289336  929982.248561
# 4004  63.947048  813.575928  2.991689  ...  2272.289336  929982.248561
# 4008  61.037365  668.597046  4.194347  ...  2272.289336  929982.248561
# 4012  59.543566  783.973083  4.161581  ...  2272.289336  929982.248561
#
#        cropland    grassland     treecover         water         ndvi  \
# 4      9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 11     9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 18     9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 25     9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# 32     9.037443  1221.246398  86858.898791  32195.290892  1830.941629
# ...         ...          ...           ...           ...          ...
# 3996  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 4000  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 4004  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 4008  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
# 4012  28.761909  7179.267694  48393.446780  12262.365566  1686.406661
#
#               aod  station       pm25
# 4    -9999.000000      201  17.250000
# 11       0.317342      201  23.000000
# 18   -9999.000000      201  28.291667
# 25   -9999.000000      201  28.791667
# 32   -9999.000000      201  24.833333
# ...           ...      ...        ...
# 3996 -9999.000000      216  39.659816
# 4000 -9999.000000      216  44.679352
# 4004     0.193722      216  30.724708
# 4008 -9999.000000      216  33.091428
# 4012 -9999.000000      216  28.854069
#
# [4015 rows x 24 columns]

# %%
df_mpair.isnull().sum()
# Out:
# i                       0
# j                       0
# lat                     0
# lon                     0
# time                    0
# pm25_3km                0
# tmp                     0
# rh                      0
# hpbl                    0
# wspd                    0
# pop                     0
# road_den_1km            0
# prim_road_len_1km    2555
# near_dist               0
# bareland                0
# builtup                 0
# cropland                0
# grassland               0
# treecover               0
# water                   0
# ndvi                  365
# aod                     7
# station                 0
# pm25                 1442
# dtype: int64

# %% [markdown]
# ## Export data

# %%
df_mpair.to_csv(conf["dataset"]["mpair"]["merged_data_dir"], index=False)

# %% [markdown]
# # Merge MPair data with station data, keep all locations

# %% [markdown]
# ## Filter out the invalid location

# %%
df_mpair_raw
# Out:
#          i   j        lat         lon       time     pm25_3km          tmp  \
# 0        0   0  11.149747  106.300443 2021-01-01 -9999.000000 -9999.000000
# 1        0   1  11.149747  106.323330 2021-01-01 -9999.000000 -9999.000000
# 2        0   2  11.149747  106.346217 2021-01-01 -9999.000000 -9999.000000
# 3        0   3  11.149747  106.369103 2021-01-01    26.040001    25.114687
# 4        0   4  11.149747  106.391990 2021-01-01    25.666174    25.121210
# ...     ..  ..        ...         ...        ...          ...          ...
# 894245  34  30  10.385233  106.987043 2022-12-31          NaN    25.815809
# 894246  34  31  10.385233  107.009930 2022-12-31          NaN    25.815809
# 894247  34  32  10.385233  107.032816 2022-12-31 -9999.000000    25.601173
# 894248  34  33  10.385233  107.055703 2022-12-31 -9999.000000    25.560753
# 894249  34  34  10.385233  107.078590 2022-12-31 -9999.000000    25.834951
#
#                  rh         hpbl         wspd  ...  prim_road_len_1km  \
# 0      -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 1      -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 2      -9999.000000 -9999.000000 -9999.000000  ...                0.0
# 3         63.633778   567.478943     4.660580  ...                NaN
# 4         62.159500   548.132568     5.052152  ...                NaN
# ...             ...          ...          ...  ...                ...
# 894245    74.737156   207.873199     3.124345  ...                NaN
# 894246    75.000397   207.873199     3.215876  ...                NaN
# 894247 -9999.000000   142.227615 -9999.000000  ...                0.0
# 894248 -9999.000000   129.865280 -9999.000000  ...                0.0
# 894249 -9999.000000   284.036316 -9999.000000  ...                0.0
#
#             near_dist      bareland       builtup      cropland  \
# 0      -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 1      -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 2      -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 3        7.265194e+01  14453.144036  30347.516088  54101.838731
# 4        1.107789e+02   4569.189136  21119.949784  76052.614180
# ...               ...           ...           ...           ...
# 894245   3.072120e+03  -9999.000000  -9999.000000  -9999.000000
# 894246   4.355371e+03  -9999.000000  -9999.000000  -9999.000000
# 894247 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 894248 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
# 894249 -1.797693e+308  -9999.000000  -9999.000000  -9999.000000
#
#             grassland      treecover         water    ndvi     aod
# 0        -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 1        -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 2        -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 3       203551.710735  683877.574149  13604.234765     NaN -9999.0
# 4       231046.865089  662859.174184   4308.164827     NaN -9999.0
# ...               ...            ...           ...     ...     ...
# 894245   -9999.000000   -9999.000000  -9999.000000     NaN -9999.0
# 894246   -9999.000000   -9999.000000  -9999.000000     NaN -9999.0
# 894247   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 894248   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
# 894249   -9999.000000   -9999.000000  -9999.000000 -9999.0 -9999.0
#
# [894250 rows x 22 columns]

# %%
# Get the start and end of i, j
mpair_start_i, mpair_end_i = sorted(df_mpair_raw["i"].unique())[0], sorted(df_mpair_raw["i"].unique())[-1]
mpair_start_j, mpair_end_j = sorted(df_mpair_raw["j"].unique())[0], sorted(df_mpair_raw["j"].unique())[-1]
print(mpair_start_i, mpair_end_i, mpair_start_j, mpair_end_j)

# Loop over every location
all_valid_location_dfs = []
for i in range(mpair_start_i, mpair_end_i + 1):
    for j in range(mpair_start_j, mpair_end_j + 1):
        # Get the data for current location
        df_mpair_current_ij = df_mpair_raw.loc[((df_mpair_raw["i"] == i) & (df_mpair_raw["j"] == j))]

        # Replace the invalid value with NaN
        df_mpair_current_ij = df_mpair_current_ij.replace(-9999, np.nan)

        # Filter out values based on pm25_3km
        total_missing = df_mpair_current_ij["pm25_3km"].isnull().sum()
        #missing_threshold = 1000
        missing_threshold = 365 # strictly
        if total_missing >= missing_threshold:
            df_mpair_current_ij.to_csv(os.path.join(conf["workspace"]["data_by_location_dir"], f"df_mpair_current_{i}_{j}_invalid.csv"), index=False)
            print(f"Location: {i}, {j} - missing = {total_missing} => invalid, skipping...")
        else:
            df_mpair_current_ij.to_csv(os.path.join(conf["workspace"]["data_by_location_dir"], f"df_mpair_current_{i}_{j}.csv"), index=False)
            all_valid_location_dfs += [df_mpair_current_ij]

# Combine all valid location data
df_mpair_raw_valid_locations = pd.concat(all_valid_location_dfs, ignore_index=True)
# Out:
# 0 34 0 34
# Location: 0, 0 - missing = 730 => invalid, skipping...
# Location: 0, 1 - missing = 730 => invalid, skipping...
# Location: 0, 2 - missing = 730 => invalid, skipping...
# Location: 0, 32 - missing = 730 => invalid, skipping...
# Location: 0, 33 - missing = 730 => invalid, skipping...
# Location: 0, 34 - missing = 730 => invalid, skipping...
# Location: 1, 0 - missing = 730 => invalid, skipping...
# Location: 1, 1 - missing = 730 => invalid, skipping...
# Location: 1, 2 - missing = 730 => invalid, skipping...
# Location: 1, 32 - missing = 730 => invalid, skipping...
# Location: 1, 33 - missing = 730 => invalid, skipping...
# Location: 1, 34 - missing = 730 => invalid, skipping...
# Location: 2, 0 - missing = 730 => invalid, skipping...
# Location: 2, 1 - missing = 730 => invalid, skipping...
# Location: 2, 2 - missing = 730 => invalid, skipping...
# Location: 2, 32 - missing = 730 => invalid, skipping...
# Location: 2, 33 - missing = 730 => invalid, skipping...
# Location: 2, 34 - missing = 730 => invalid, skipping...
# Location: 3, 0 - missing = 730 => invalid, skipping...
# Location: 3, 1 - missing = 730 => invalid, skipping...
# Location: 3, 2 - missing = 730 => invalid, skipping...
# Location: 3, 32 - missing = 730 => invalid, skipping...
# Location: 3, 33 - missing = 730 => invalid, skipping...
# Location: 3, 34 - missing = 730 => invalid, skipping...
# Location: 4, 0 - missing = 730 => invalid, skipping...
# Location: 4, 1 - missing = 730 => invalid, skipping...
# Location: 4, 2 - missing = 730 => invalid, skipping...
# Location: 4, 32 - missing = 730 => invalid, skipping...
# Location: 4, 33 - missing = 730 => invalid, skipping...
# Location: 4, 34 - missing = 730 => invalid, skipping...
# Location: 5, 0 - missing = 730 => invalid, skipping...
# Location: 5, 1 - missing = 730 => invalid, skipping...
# Location: 5, 2 - missing = 730 => invalid, skipping...
# Location: 5, 32 - missing = 730 => invalid, skipping...
# Location: 5, 33 - missing = 730 => invalid, skipping...
# Location: 5, 34 - missing = 730 => invalid, skipping...
# Location: 6, 0 - missing = 730 => invalid, skipping...
# Location: 6, 1 - missing = 730 => invalid, skipping...
# Location: 6, 2 - missing = 730 => invalid, skipping...
# Location: 6, 32 - missing = 730 => invalid, skipping...
# Location: 6, 33 - missing = 730 => invalid, skipping...
# Location: 6, 34 - missing = 730 => invalid, skipping...
# Location: 7, 0 - missing = 730 => invalid, skipping...
# Location: 7, 1 - missing = 730 => invalid, skipping...
# Location: 7, 2 - missing = 730 => invalid, skipping...
# Location: 7, 32 - missing = 730 => invalid, skipping...
# Location: 7, 33 - missing = 730 => invalid, skipping...
# Location: 7, 34 - missing = 730 => invalid, skipping...
# Location: 8, 0 - missing = 730 => invalid, skipping...
# Location: 8, 1 - missing = 730 => invalid, skipping...
# Location: 8, 2 - missing = 730 => invalid, skipping...
# Location: 8, 32 - missing = 730 => invalid, skipping...
# Location: 8, 33 - missing = 730 => invalid, skipping...
# Location: 8, 34 - missing = 730 => invalid, skipping...
# Location: 9, 0 - missing = 730 => invalid, skipping...
# Location: 9, 1 - missing = 730 => invalid, skipping...
# Location: 9, 2 - missing = 730 => invalid, skipping...
# Location: 9, 32 - missing = 730 => invalid, skipping...
# Location: 9, 33 - missing = 730 => invalid, skipping...
# Location: 9, 34 - missing = 730 => invalid, skipping...
# Location: 10, 0 - missing = 730 => invalid, skipping...
# Location: 10, 1 - missing = 730 => invalid, skipping...
# Location: 10, 2 - missing = 730 => invalid, skipping...
# Location: 10, 32 - missing = 730 => invalid, skipping...
# Location: 10, 33 - missing = 730 => invalid, skipping...
# Location: 10, 34 - missing = 730 => invalid, skipping...
# Location: 11, 0 - missing = 730 => invalid, skipping...
# Location: 11, 1 - missing = 730 => invalid, skipping...
# Location: 11, 2 - missing = 730 => invalid, skipping...
# Location: 11, 32 - missing = 730 => invalid, skipping...
# Location: 11, 33 - missing = 730 => invalid, skipping...
# Location: 11, 34 - missing = 730 => invalid, skipping...
# Location: 12, 0 - missing = 730 => invalid, skipping...
# Location: 12, 1 - missing = 730 => invalid, skipping...
# Location: 12, 2 - missing = 730 => invalid, skipping...
# Location: 12, 32 - missing = 730 => invalid, skipping...
# Location: 12, 33 - missing = 730 => invalid, skipping...
# Location: 12, 34 - missing = 730 => invalid, skipping...
# Location: 13, 0 - missing = 730 => invalid, skipping...
# Location: 13, 1 - missing = 730 => invalid, skipping...
# Location: 13, 2 - missing = 730 => invalid, skipping...
# Location: 13, 32 - missing = 730 => invalid, skipping...
# Location: 13, 33 - missing = 730 => invalid, skipping...
# Location: 13, 34 - missing = 730 => invalid, skipping...
# Location: 14, 0 - missing = 730 => invalid, skipping...
# Location: 14, 1 - missing = 730 => invalid, skipping...
# Location: 14, 2 - missing = 730 => invalid, skipping...
# Location: 14, 32 - missing = 730 => invalid, skipping...
# Location: 14, 33 - missing = 730 => invalid, skipping...
# Location: 14, 34 - missing = 730 => invalid, skipping...
# Location: 15, 0 - missing = 730 => invalid, skipping...
# Location: 15, 1 - missing = 730 => invalid, skipping...
# Location: 15, 2 - missing = 730 => invalid, skipping...
# Location: 15, 32 - missing = 730 => invalid, skipping...
# Location: 15, 33 - missing = 730 => invalid, skipping...
# Location: 15, 34 - missing = 730 => invalid, skipping...
# Location: 16, 0 - missing = 730 => invalid, skipping...
# Location: 16, 1 - missing = 730 => invalid, skipping...
# Location: 16, 2 - missing = 730 => invalid, skipping...
# Location: 16, 32 - missing = 730 => invalid, skipping...
# Location: 16, 33 - missing = 730 => invalid, skipping...
# Location: 16, 34 - missing = 730 => invalid, skipping...
# Location: 17, 0 - missing = 730 => invalid, skipping...
# Location: 17, 1 - missing = 730 => invalid, skipping...
# Location: 17, 2 - missing = 730 => invalid, skipping...
# Location: 17, 32 - missing = 730 => invalid, skipping...
# Location: 17, 33 - missing = 730 => invalid, skipping...
# Location: 17, 34 - missing = 730 => invalid, skipping...
# Location: 18, 0 - missing = 730 => invalid, skipping...
# Location: 18, 1 - missing = 730 => invalid, skipping...
# Location: 18, 2 - missing = 730 => invalid, skipping...
# Location: 18, 32 - missing = 730 => invalid, skipping...
# Location: 18, 33 - missing = 730 => invalid, skipping...
# Location: 18, 34 - missing = 730 => invalid, skipping...
# Location: 19, 0 - missing = 730 => invalid, skipping...
# Location: 19, 1 - missing = 730 => invalid, skipping...
# Location: 19, 2 - missing = 730 => invalid, skipping...
# Location: 19, 32 - missing = 730 => invalid, skipping...
# Location: 19, 33 - missing = 730 => invalid, skipping...
# Location: 19, 34 - missing = 730 => invalid, skipping...
# Location: 20, 0 - missing = 730 => invalid, skipping...
# Location: 20, 1 - missing = 730 => invalid, skipping...
# Location: 20, 2 - missing = 730 => invalid, skipping...
# Location: 20, 32 - missing = 730 => invalid, skipping...
# Location: 20, 33 - missing = 730 => invalid, skipping...
# Location: 20, 34 - missing = 730 => invalid, skipping...
# Location: 21, 0 - missing = 730 => invalid, skipping...
# Location: 21, 1 - missing = 730 => invalid, skipping...
# Location: 21, 2 - missing = 730 => invalid, skipping...
# Location: 21, 32 - missing = 730 => invalid, skipping...
# Location: 21, 33 - missing = 730 => invalid, skipping...
# Location: 21, 34 - missing = 730 => invalid, skipping...
# Location: 22, 0 - missing = 730 => invalid, skipping...
# Location: 22, 1 - missing = 730 => invalid, skipping...
# Location: 22, 2 - missing = 730 => invalid, skipping...
# Location: 22, 32 - missing = 730 => invalid, skipping...
# Location: 22, 33 - missing = 730 => invalid, skipping...
# Location: 22, 34 - missing = 730 => invalid, skipping...
# Location: 23, 0 - missing = 730 => invalid, skipping...
# Location: 23, 1 - missing = 730 => invalid, skipping...
# Location: 23, 2 - missing = 730 => invalid, skipping...
# Location: 23, 31 - missing = 365 => invalid, skipping...
# Location: 23, 32 - missing = 730 => invalid, skipping...
# Location: 23, 33 - missing = 730 => invalid, skipping...
# Location: 23, 34 - missing = 730 => invalid, skipping...
# Location: 24, 0 - missing = 730 => invalid, skipping...
# Location: 24, 1 - missing = 730 => invalid, skipping...
# Location: 24, 2 - missing = 730 => invalid, skipping...
# Location: 24, 31 - missing = 365 => invalid, skipping...
# Location: 24, 32 - missing = 730 => invalid, skipping...
# Location: 24, 33 - missing = 730 => invalid, skipping...
# Location: 24, 34 - missing = 730 => invalid, skipping...
# Location: 25, 0 - missing = 730 => invalid, skipping...
# Location: 25, 1 - missing = 730 => invalid, skipping...
# Location: 25, 2 - missing = 730 => invalid, skipping...
# Location: 25, 29 - missing = 365 => invalid, skipping...
# Location: 25, 30 - missing = 365 => invalid, skipping...
# Location: 25, 31 - missing = 365 => invalid, skipping...
# Location: 25, 32 - missing = 730 => invalid, skipping...
# Location: 25, 33 - missing = 730 => invalid, skipping...
# Location: 25, 34 - missing = 730 => invalid, skipping...
# Location: 26, 0 - missing = 730 => invalid, skipping...
# Location: 26, 1 - missing = 730 => invalid, skipping...
# Location: 26, 2 - missing = 730 => invalid, skipping...
# Location: 26, 29 - missing = 365 => invalid, skipping...
# Location: 26, 30 - missing = 365 => invalid, skipping...
# Location: 26, 31 - missing = 365 => invalid, skipping...
# Location: 26, 32 - missing = 730 => invalid, skipping...
# Location: 26, 33 - missing = 730 => invalid, skipping...
# Location: 26, 34 - missing = 730 => invalid, skipping...
# Location: 27, 0 - missing = 730 => invalid, skipping...
# Location: 27, 1 - missing = 730 => invalid, skipping...
# Location: 27, 2 - missing = 730 => invalid, skipping...
# Location: 27, 32 - missing = 730 => invalid, skipping...
# Location: 27, 33 - missing = 730 => invalid, skipping...
# Location: 27, 34 - missing = 730 => invalid, skipping...
# Location: 28, 0 - missing = 730 => invalid, skipping...
# Location: 28, 1 - missing = 730 => invalid, skipping...
# Location: 28, 2 - missing = 730 => invalid, skipping...
# Location: 28, 32 - missing = 730 => invalid, skipping...
# Location: 28, 33 - missing = 730 => invalid, skipping...
# Location: 28, 34 - missing = 730 => invalid, skipping...
# Location: 29, 0 - missing = 730 => invalid, skipping...
# Location: 29, 1 - missing = 730 => invalid, skipping...
# Location: 29, 2 - missing = 730 => invalid, skipping...
# Location: 29, 31 - missing = 365 => invalid, skipping...
# Location: 29, 32 - missing = 730 => invalid, skipping...
# Location: 29, 33 - missing = 730 => invalid, skipping...
# Location: 29, 34 - missing = 730 => invalid, skipping...
# Location: 30, 0 - missing = 730 => invalid, skipping...
# Location: 30, 1 - missing = 730 => invalid, skipping...
# Location: 30, 2 - missing = 730 => invalid, skipping...
# Location: 30, 28 - missing = 365 => invalid, skipping...
# Location: 30, 29 - missing = 365 => invalid, skipping...
# Location: 30, 30 - missing = 365 => invalid, skipping...
# Location: 30, 31 - missing = 365 => invalid, skipping...
# Location: 30, 32 - missing = 730 => invalid, skipping...
# Location: 30, 33 - missing = 730 => invalid, skipping...
# Location: 30, 34 - missing = 730 => invalid, skipping...
# Location: 31, 0 - missing = 730 => invalid, skipping...
# Location: 31, 1 - missing = 730 => invalid, skipping...
# Location: 31, 2 - missing = 730 => invalid, skipping...
# Location: 31, 28 - missing = 365 => invalid, skipping...
# Location: 31, 29 - missing = 365 => invalid, skipping...
# Location: 31, 30 - missing = 365 => invalid, skipping...
# Location: 31, 31 - missing = 365 => invalid, skipping...
# Location: 31, 32 - missing = 730 => invalid, skipping...
# Location: 31, 33 - missing = 730 => invalid, skipping...
# Location: 31, 34 - missing = 730 => invalid, skipping...
# Location: 32, 0 - missing = 730 => invalid, skipping...
# Location: 32, 1 - missing = 730 => invalid, skipping...
# Location: 32, 2 - missing = 730 => invalid, skipping...
# Location: 32, 22 - missing = 365 => invalid, skipping...
# Location: 32, 23 - missing = 365 => invalid, skipping...
# Location: 32, 29 - missing = 365 => invalid, skipping...
# Location: 32, 30 - missing = 365 => invalid, skipping...
# Location: 32, 31 - missing = 365 => invalid, skipping...
# Location: 32, 32 - missing = 730 => invalid, skipping...
# Location: 32, 33 - missing = 730 => invalid, skipping...
# Location: 32, 34 - missing = 730 => invalid, skipping...
# Location: 33, 0 - missing = 730 => invalid, skipping...
# Location: 33, 1 - missing = 730 => invalid, skipping...
# Location: 33, 2 - missing = 730 => invalid, skipping...
# Location: 33, 22 - missing = 365 => invalid, skipping...
# Location: 33, 23 - missing = 365 => invalid, skipping...
# Location: 33, 24 - missing = 365 => invalid, skipping...
# Location: 33, 25 - missing = 365 => invalid, skipping...
# Location: 33, 28 - missing = 365 => invalid, skipping...
# Location: 33, 29 - missing = 365 => invalid, skipping...
# Location: 33, 30 - missing = 365 => invalid, skipping...
# Location: 33, 31 - missing = 365 => invalid, skipping...
# Location: 33, 32 - missing = 730 => invalid, skipping...
# Location: 33, 33 - missing = 730 => invalid, skipping...
# Location: 33, 34 - missing = 730 => invalid, skipping...
# Location: 34, 0 - missing = 730 => invalid, skipping...
# Location: 34, 1 - missing = 730 => invalid, skipping...
# Location: 34, 2 - missing = 730 => invalid, skipping...
# Location: 34, 22 - missing = 365 => invalid, skipping...
# Location: 34, 23 - missing = 730 => invalid, skipping...
# Location: 34, 24 - missing = 730 => invalid, skipping...
# Location: 34, 25 - missing = 365 => invalid, skipping...
# Location: 34, 28 - missing = 365 => invalid, skipping...
# Location: 34, 29 - missing = 365 => invalid, skipping...
# Location: 34, 30 - missing = 365 => invalid, skipping...
# Location: 34, 31 - missing = 730 => invalid, skipping...
# Location: 34, 32 - missing = 730 => invalid, skipping...
# Location: 34, 33 - missing = 730 => invalid, skipping...
# Location: 34, 34 - missing = 730 => invalid, skipping...

# %%
df_mpair_raw_valid_locations
# Out:
#          i   j        lat         lon       time   pm25_3km        tmp  \
# 0        0   3  11.149747  106.369103 2021-01-01  26.040001  25.114687
# 1        0   3  11.149747  106.369103 2021-01-02  39.470001  24.043423
# 2        0   3  11.149747  106.369103 2021-01-03  40.619999  25.058735
# 3        0   3  11.149747  106.369103 2021-01-04  40.330002  25.554197
# 4        0   3  11.149747  106.369103 2021-01-05  50.009998  25.037054
# ...     ..  ..        ...         ...        ...        ...        ...
# 713205  34  27  10.385233  106.918383 2022-12-27  19.874584  24.644707
# 713206  34  27  10.385233  106.918383 2022-12-28  17.509365  25.071791
# 713207  34  27  10.385233  106.918383 2022-12-29  18.428423  25.458431
# 713208  34  27  10.385233  106.918383 2022-12-30  12.645213  24.636055
# 713209  34  27  10.385233  106.918383 2022-12-31  16.706522  24.775455
#
#                rh        hpbl      wspd  ...  prim_road_len_1km   near_dist  \
# 0       63.633778  567.478943  4.660580  ...                NaN   72.651942
# 1       69.082085  485.584290  3.288929  ...                NaN   72.651942
# 2       67.647362  403.936310  2.731468  ...                NaN   72.651942
# 3       71.023094  704.476807  3.522596  ...                NaN   72.651942
# 4       74.029236  534.426575  3.223711  ...                NaN   72.651942
# ...           ...         ...       ...  ...                ...         ...
# 713205  76.055573  441.420624  2.561953  ...                NaN  365.912235
# 713206  78.165489  403.261658  2.126233  ...                NaN  365.912235
# 713207  79.421234  425.696411  1.909332  ...                NaN  365.912235
# 713208  76.198395  241.369736  2.530340  ...                NaN  365.912235
# 713209  76.337906  432.667236  2.036375  ...                NaN  365.912235
#
#             bareland       builtup      cropland      grassland  \
# 0       14453.144036  30347.516088  54101.838731  203551.710735
# 1       14453.144036  30347.516088  54101.838731  203551.710735
# 2       14453.144036  30347.516088  54101.838731  203551.710735
# 3       14453.144036  30347.516088  54101.838731  203551.710735
# 4       14453.144036  30347.516088  54101.838731  203551.710735
# ...              ...           ...           ...            ...
# 713205  24482.287914  48934.328055   8711.125789  154921.372745
# 713206  24482.287914  48934.328055   8711.125789  154921.372745
# 713207  24482.287914  48934.328055   8711.125789  154921.372745
# 713208  24482.287914  48934.328055   8711.125789  154921.372745
# 713209  24482.287914  48934.328055   8711.125789  154921.372745
#
#             treecover          water  ndvi       aod
# 0       683877.574149   13604.234765   NaN       NaN
# 1       683877.574149   13604.234765   NaN       NaN
# 2       683877.574149   13604.234765   NaN       NaN
# 3       683877.574149   13604.234765   NaN  0.555355
# 4       683877.574149   13604.234765   NaN       NaN
# ...               ...            ...   ...       ...
# 713205   91390.837123  426893.893429   NaN       NaN
# 713206   91390.837123  426893.893429   NaN       NaN
# 713207   91390.837123  426893.893429   NaN  0.174487
# 713208   91390.837123  426893.893429   NaN       NaN
# 713209   91390.837123  426893.893429   NaN       NaN
#
# [713210 rows x 22 columns]

# %%
df_mpair_raw_valid_locations.isnull().sum()
# Out:
# i                         0
# j                         0
# lat                       0
# lon                       0
# time                      0
# pm25_3km                  0
# tmp                       0
# rh                        0
# hpbl                      0
# wspd                      0
# pop                       0
# road_den_1km              0
# prim_road_len_1km    708830
# near_dist                 0
# bareland                  0
# builtup                   0
# cropland                  0
# grassland                 0
# treecover                 0
# water                     0
# ndvi                 556260
# aod                  429477
# dtype: int64

# %% [markdown]
# ## Start merging

# %%
df_mpair_valid_locations = pd.merge(df_mpair_raw_valid_locations, df_station, how="left", on=["i", "j", "time"])
df_mpair_valid_locations
# Out:
#          i   j      lat_x       lon_x       time   pm25_3km        tmp  \
# 0        0   3  11.149747  106.369103 2021-01-01  26.040001  25.114687
# 1        0   3  11.149747  106.369103 2021-01-02  39.470001  24.043423
# 2        0   3  11.149747  106.369103 2021-01-03  40.619999  25.058735
# 3        0   3  11.149747  106.369103 2021-01-04  40.330002  25.554197
# 4        0   3  11.149747  106.369103 2021-01-05  50.009998  25.037054
# ...     ..  ..        ...         ...        ...        ...        ...
# 713205  34  27  10.385233  106.918383 2022-12-27  19.874584  24.644707
# 713206  34  27  10.385233  106.918383 2022-12-28  17.509365  25.071791
# 713207  34  27  10.385233  106.918383 2022-12-29  18.428423  25.458431
# 713208  34  27  10.385233  106.918383 2022-12-30  12.645213  24.636055
# 713209  34  27  10.385233  106.918383 2022-12-31  16.706522  24.775455
#
#                rh        hpbl      wspd  ...      cropland      grassland  \
# 0       63.633778  567.478943  4.660580  ...  54101.838731  203551.710735
# 1       69.082085  485.584290  3.288929  ...  54101.838731  203551.710735
# 2       67.647362  403.936310  2.731468  ...  54101.838731  203551.710735
# 3       71.023094  704.476807  3.522596  ...  54101.838731  203551.710735
# 4       74.029236  534.426575  3.223711  ...  54101.838731  203551.710735
# ...           ...         ...       ...  ...           ...            ...
# 713205  76.055573  441.420624  2.561953  ...   8711.125789  154921.372745
# 713206  78.165489  403.261658  2.126233  ...   8711.125789  154921.372745
# 713207  79.421234  425.696411  1.909332  ...   8711.125789  154921.372745
# 713208  76.198395  241.369736  2.530340  ...   8711.125789  154921.372745
# 713209  76.337906  432.667236  2.036375  ...   8711.125789  154921.372745
#
#             treecover          water  ndvi       aod  station  lon_y  lat_y  \
# 0       683877.574149   13604.234765   NaN       NaN      NaN    NaN    NaN
# 1       683877.574149   13604.234765   NaN       NaN      NaN    NaN    NaN
# 2       683877.574149   13604.234765   NaN       NaN      NaN    NaN    NaN
# 3       683877.574149   13604.234765   NaN  0.555355      NaN    NaN    NaN
# 4       683877.574149   13604.234765   NaN       NaN      NaN    NaN    NaN
# ...               ...            ...   ...       ...      ...    ...    ...
# 713205   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
# 713206   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
# 713207   91390.837123  426893.893429   NaN  0.174487      NaN    NaN    NaN
# 713208   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
# 713209   91390.837123  426893.893429   NaN       NaN      NaN    NaN    NaN
#
#         pm25
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 713205   NaN
# 713206   NaN
# 713207   NaN
# 713208   NaN
# 713209   NaN
#
# [713210 rows x 26 columns]

# %% [markdown]
# ## Handle metadata

# %%
# Drop redundant columns
df_mpair_valid_locations.drop(columns=["lat_y", "lon_y"], axis=1, inplace=True)

# Rename "lat_x" to "lat", "lon_x" to "lon"
df_mpair_valid_locations.rename(columns={"lat_x": "lat", "lon_x": "lon"}, inplace=True)

# Sort data by location then "time"
df_mpair_valid_locations.sort_values(by=["i", "j", "time"], inplace=True)

df_mpair_valid_locations
# Out:
#          i   j        lat         lon       time   pm25_3km        tmp  \
# 0        0   3  11.149747  106.369103 2021-01-01  26.040001  25.114687
# 1        0   3  11.149747  106.369103 2021-01-02  39.470001  24.043423
# 2        0   3  11.149747  106.369103 2021-01-03  40.619999  25.058735
# 3        0   3  11.149747  106.369103 2021-01-04  40.330002  25.554197
# 4        0   3  11.149747  106.369103 2021-01-05  50.009998  25.037054
# ...     ..  ..        ...         ...        ...        ...        ...
# 713205  34  27  10.385233  106.918383 2022-12-27  19.874584  24.644707
# 713206  34  27  10.385233  106.918383 2022-12-28  17.509365  25.071791
# 713207  34  27  10.385233  106.918383 2022-12-29  18.428423  25.458431
# 713208  34  27  10.385233  106.918383 2022-12-30  12.645213  24.636055
# 713209  34  27  10.385233  106.918383 2022-12-31  16.706522  24.775455
#
#                rh        hpbl      wspd  ...      bareland       builtup  \
# 0       63.633778  567.478943  4.660580  ...  14453.144036  30347.516088
# 1       69.082085  485.584290  3.288929  ...  14453.144036  30347.516088
# 2       67.647362  403.936310  2.731468  ...  14453.144036  30347.516088
# 3       71.023094  704.476807  3.522596  ...  14453.144036  30347.516088
# 4       74.029236  534.426575  3.223711  ...  14453.144036  30347.516088
# ...           ...         ...       ...  ...           ...           ...
# 713205  76.055573  441.420624  2.561953  ...  24482.287914  48934.328055
# 713206  78.165489  403.261658  2.126233  ...  24482.287914  48934.328055
# 713207  79.421234  425.696411  1.909332  ...  24482.287914  48934.328055
# 713208  76.198395  241.369736  2.530340  ...  24482.287914  48934.328055
# 713209  76.337906  432.667236  2.036375  ...  24482.287914  48934.328055
#
#             cropland      grassland      treecover          water  ndvi  \
# 0       54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 1       54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 2       54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 3       54101.838731  203551.710735  683877.574149   13604.234765   NaN
# 4       54101.838731  203551.710735  683877.574149   13604.234765   NaN
# ...              ...            ...            ...            ...   ...
# 713205   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 713206   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 713207   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 713208   8711.125789  154921.372745   91390.837123  426893.893429   NaN
# 713209   8711.125789  154921.372745   91390.837123  426893.893429   NaN
#
#              aod  station  pm25
# 0            NaN      NaN   NaN
# 1            NaN      NaN   NaN
# 2            NaN      NaN   NaN
# 3       0.555355      NaN   NaN
# 4            NaN      NaN   NaN
# ...          ...      ...   ...
# 713205       NaN      NaN   NaN
# 713206       NaN      NaN   NaN
# 713207  0.174487      NaN   NaN
# 713208       NaN      NaN   NaN
# 713209       NaN      NaN   NaN
#
# [713210 rows x 24 columns]

# %% [markdown]
# ## Export data

# %%
df_mpair_valid_locations.to_csv(conf["dataset"]["mpair"]["merged_data_dir_all_locations"], index=False)
