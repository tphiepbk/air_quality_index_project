# %%
# === Cell 1: Imports & config chung cho LightGBM NO2 ===
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

try:
    import lightgbm as lgb
except ImportError:
    print("Chưa cài lightgbm: !pip install lightgbm")

# Cấu hình chung
DATA_DIR = "/le_thanh_van_118/workspace/hiep_workspace/air_quality_index_project/dataset/merged-data/by-station"
STATION_IDS = ["211", "212", "213", "214", "215", "216"]

TARGET_COL = "NO2_quantrac"

# Các feature gốc dùng cho LightGBM (có thể thêm/bớt)
BASE_FEATURE_COLS = [
    "NO2_quantrac",
    "PM25_quantrac",
    "O3_quantrac",
    "CO_quantrac",
    "SO2_quantrac",
    "Temperature_quantrac",
    "Humid_quantrac",
]

# Các lag và rolling window dùng làm feature
LAG_STEPS = [1, 2, 3, 6, 12, 24, 48, 72]
ROLL_WINDOWS = [3, 6, 12, 24]

# Các horizon muốn dự báo (giờ)
#HORIZONS = [1, 2, 3, 4, 5, 24, 72]
HORIZONS = list(range(1, 73)) 

RANDOM_STATE = 42

# %%
# === Cell 2: Load & gộp dữ liệu từ các trạm ===

def load_station_csv(station_id, data_dir=DATA_DIR):
    csv_path = os.path.join(data_dir, f"{station_id}.csv")
    df = pd.read_csv(csv_path)
    
    # Chuẩn hóa cột thời gian
    df["date"] = pd.to_datetime(df["date"])
    df = df.sort_values("date").reset_index(drop=True)
    
    # Xoá cột index thừa nếu có
    if "Unnamed: 0" in df.columns:
        df = df.drop(columns=["Unnamed: 0"])
    
    # Thêm thông tin trạm
    df["station_id"] = int(station_id)
    return df

dfs = []
for sid in STATION_IDS:
    df_sid = load_station_csv(sid, DATA_DIR)
    dfs.append(df_sid)

df_all = pd.concat(dfs, ignore_index=True)
df_all = df_all.sort_values(["station_id", "date"]).reset_index(drop=True)

print("Kích thước dữ liệu gộp:", df_all.shape)
df_all.head()
# Out:
# Kích thước dữ liệu gộp: (92966, 15)
#                  date  TSP_quantrac  PM25_quantrac  O3_quantrac  CO_quantrac  \
# 0 2021-02-23 21:00:00     32.935714      15.604762    55.431381    90.000000
# 1 2021-02-23 22:00:00     30.932353      14.594118    58.197176  1200.603529
# 2 2021-02-23 23:00:00     27.645000      13.436667    55.029433  1177.897000
# 3 2021-02-24 00:00:00     24.380000      12.365000    54.767700    90.000000
# 4 2021-02-24 01:00:00     22.521667      11.636667    53.786200    90.000000
#
#    NO2_quantrac  Temperature_quantrac  Humid_quantrac  PM25_cmaq  PM10_cmaq  \
# 0    112.740762             28.361905       63.188095        NaN        NaN
# 1    112.366471             28.320588       63.773529        NaN        NaN
# 2    112.700433             28.336667       64.205000        NaN        NaN
# 3    112.480867             28.305000       64.735000        NaN        NaN
# 4    114.331500             28.300000       65.188333        NaN        NaN
#
#    O3_cmaq  SO2_cmaq  PM25_vientham  station_id  SO2_quantrac
# 0      NaN       NaN            NaN         211           NaN
# 1      NaN       NaN            NaN         211           NaN
# 2      NaN       NaN            NaN         211           NaN
# 3      NaN       NaN            NaN         211           NaN
# 4      NaN       NaN            NaN         211           NaN

# %%
# === Cell 3: Hàm tạo feature thời gian, lag, rolling ===

def add_time_features(df, time_col="date"):
    df = df.copy()
    df["hour"] = df[time_col].dt.hour
    df["dayofweek"] = df[time_col].dt.dayofweek
    df["month"] = df[time_col].dt.month
    return df

def add_lag_features(df, group_col, target_cols, lag_steps):
    df = df.copy()
    df = df.sort_values(["station_id", "date"])
    
    for col in target_cols:
        for lag in lag_steps:
            df[f"{col}_lag{lag}"] = df.groupby(group_col)[col].shift(lag)
    return df

def add_rolling_features(df, group_col, target_cols, windows):
    df = df.copy()
    df = df.sort_values(["station_id", "date"])
    
    for col in target_cols:
        for w in windows:
            df[f"{col}_roll{w}_mean"] = (
                df.groupby(group_col)[col]
                  .shift(1)              # dùng quá khứ, tránh leak
                  .rolling(window=w, min_periods=1)
                  .mean()
                  .reset_index(level=0, drop=True)
            )
            df[f"{col}_roll{w}_std"] = (
                df.groupby(group_col)[col]
                  .shift(1)
                  .rolling(window=w, min_periods=1)
                  .std()
                  .reset_index(level=0, drop=True)
            )
    return df

# Áp dụng feature engineering
df_feat = add_time_features(df_all)
df_feat = add_lag_features(df_feat, group_col="station_id",
                           target_cols=BASE_FEATURE_COLS,
                           lag_steps=LAG_STEPS)
df_feat = add_rolling_features(df_feat, group_col="station_id",
                               target_cols=[TARGET_COL],
                               windows=ROLL_WINDOWS)

print("Sau khi thêm feature:", df_feat.shape)
df_feat.head()
# Out:
# Sau khi thêm feature: (92966, 82)
#                  date  TSP_quantrac  PM25_quantrac  O3_quantrac  CO_quantrac  \
# 0 2021-02-23 21:00:00     32.935714      15.604762    55.431381    90.000000
# 1 2021-02-23 22:00:00     30.932353      14.594118    58.197176  1200.603529
# 2 2021-02-23 23:00:00     27.645000      13.436667    55.029433  1177.897000
# 3 2021-02-24 00:00:00     24.380000      12.365000    54.767700    90.000000
# 4 2021-02-24 01:00:00     22.521667      11.636667    53.786200    90.000000
#
#    NO2_quantrac  Temperature_quantrac  Humid_quantrac  PM25_cmaq  PM10_cmaq  \
# 0    112.740762             28.361905       63.188095        NaN        NaN
# 1    112.366471             28.320588       63.773529        NaN        NaN
# 2    112.700433             28.336667       64.205000        NaN        NaN
# 3    112.480867             28.305000       64.735000        NaN        NaN
# 4    114.331500             28.300000       65.188333        NaN        NaN
#
#    ...  Humid_quantrac_lag48  Humid_quantrac_lag72  NO2_quantrac_roll3_mean  \
# 0  ...                   NaN                   NaN                      NaN
# 1  ...                   NaN                   NaN               112.740762
# 2  ...                   NaN                   NaN               112.553616
# 3  ...                   NaN                   NaN               112.602555
# 4  ...                   NaN                   NaN               112.515924
#
#    NO2_quantrac_roll3_std  NO2_quantrac_roll6_mean  NO2_quantrac_roll6_std  \
# 0                     NaN                      NaN                     NaN
# 1                     NaN               112.740762                     NaN
# 2                0.264664               112.553616                0.264664
# 3                0.205447               112.602555                0.205447
# 4                0.169719               112.572133                0.178441
#
#    NO2_quantrac_roll12_mean  NO2_quantrac_roll12_std  \
# 0                       NaN                      NaN
# 1                112.740762                      NaN
# 2                112.553616                 0.264664
# 3                112.602555                 0.205447
# 4                112.572133                 0.178441
#
#    NO2_quantrac_roll24_mean  NO2_quantrac_roll24_std
# 0                       NaN                      NaN
# 1                112.740762                      NaN
# 2                112.553616                 0.264664
# 3                112.602555                 0.205447
# 4                112.572133                 0.178441
#
# [5 rows x 82 columns]

# %%
# === Cell 4: Tạo dataset supervised cho 1 horizon — FIX trùng station_id ===

def build_supervised_for_horizon(df, horizon_h, target_col=TARGET_COL):
    df = df.copy()
    df = df.sort_values(["station_id", "date"])
    
    target_name = f"{target_col}_t_plus_{horizon_h}h"
    
    # Mục tiêu: NO2 tại tương lai t+h
    df[target_name] = df.groupby("station_id")[target_col].shift(-horizon_h)
    
    # Các cột không dùng làm feature
    ignore_cols = ["date", target_col, target_name]
    feature_cols = [c for c in df.columns if c not in ignore_cols]
    
    # Loại trùng tên cột (nếu có)
    feature_cols = list(dict.fromkeys(feature_cols))
    
    # KHÔNG cho station_id vào feature, chỉ giữ trong meta
    feature_cols_no_sid = [c for c in feature_cols if c != "station_id"]
    
    # data chỉ có 1 cột station_id (ở phần meta)
    data = df[["date", "station_id"] + feature_cols_no_sid + [target_name]].dropna()
    
    X = data[feature_cols_no_sid]
    y = data[target_name]
    meta = data[["date", "station_id"]]
    
    return X, y, meta, feature_cols_no_sid


# Ví dụ test cho horizon = 1
X_h1, y_h1, meta_h1, feat_cols = build_supervised_for_horizon(df_feat, horizon_h=1)
print("Horizon 1h:", X_h1.shape, y_h1.shape)
# Out:
# Horizon 1h: (5416, 79) (5416,)

# %%
# === Cell 5: Hàm split train/val/test theo thời gian ===

def time_based_split(X, y, meta,
                     train_ratio=0.7,
                     val_ratio=0.15):
    """
    Chia theo thứ tự thời gian (sau khi đã sort).
    """
    n = len(X)
    train_end = int(n * train_ratio)
    val_end = int(n * (train_ratio + val_ratio))
    
    X_train = X.iloc[:train_end]
    y_train = y.iloc[:train_end]
    meta_train = meta.iloc[:train_end]
    
    X_val = X.iloc[train_end:val_end]
    y_val = y.iloc[train_end:val_end]
    meta_val = meta.iloc[train_end:val_end]
    
    X_test = X.iloc[val_end:]
    y_test = y.iloc[val_end:]
    meta_test = meta.iloc[val_end:]
    
    return (X_train, y_train, meta_train,
            X_val, y_val, meta_val,
            X_test, y_test, meta_test)

# %%
# === Cell 6: Metrics cho NO2 ===

def compute_metrics(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    
    # Mean Bias Error
    mbe = np.mean(y_pred - y_true)
    
    # MNBE (%) ~ giống chị dùng: trung bình (pred-true)/true * 100
    yt_nonzero = np.where(y_true == 0, np.nan, y_true)
    mnbe = np.nanmean((y_pred - yt_nonzero) / yt_nonzero) * 100.0
    
    # Pearson r (có kiểm tra độ lệch chuẩn)
    if np.std(y_true) < 1e-6 or np.std(y_pred) < 1e-6:
        r = np.nan
    else:
        r = np.corrcoef(y_true, y_pred)[0, 1]
    
    return {
        "RMSE": rmse,
        "MAE": mae,
        "MBE": mbe,
        "MNBE": mnbe,
        "r": r,
        "n_samples": len(y_true),
    }

# %%
# === Cell 7: Train LightGBM cho 1 horizon — bản đơn giản, sạch lỗi ===

def train_lgbm_for_horizon(df_feat,
                           horizon_h,
                           target_col=TARGET_COL,
                           learning_rate=0.05,
                           n_estimators=2000,
                           early_stopping_rounds=100):

    # Build supervised dataset
    X, y, meta, feature_cols = build_supervised_for_horizon(
        df_feat, horizon_h=horizon_h, target_col=target_col
    )
    
    # Chia train/val/test theo thời gian
    (X_train, y_train, meta_train,
     X_val, y_val, meta_val,
     X_test, y_test, meta_test) = time_based_split(X, y, meta)
    
    # KHÔNG xử lý station_id nữa, để nguyên dtype hiện tại
    # Nếu muốn chắc ăn có thể ép toàn bộ về float:
    # X_train = X_train.astype(float)
    # X_val   = X_val.astype(float)
    # X_test  = X_test.astype(float)

    # Dataset cho LightGBM
    lgb_train = lgb.Dataset(X_train, label=y_train)
    lgb_val   = lgb.Dataset(X_val,   label=y_val, reference=lgb_train)
    
    params = {
        "objective": "regression",
        "metric": "rmse",
        "learning_rate": learning_rate,
        "num_leaves": 63,
        "feature_fraction": 0.9,
        "bagging_fraction": 0.8,
        "bagging_freq": 1,
        "verbosity": -1,
        "device": "cuda",
        "seed": RANDOM_STATE,
    }
    
    # Early stopping dùng callback (tương thích nhiều version LightGBM)
    callbacks = [
        lgb.early_stopping(stopping_rounds=early_stopping_rounds),
        lgb.log_evaluation(period=100),
    ]
    
    model = lgb.train(
        params,
        lgb_train,
        num_boost_round=n_estimators,
        valid_sets=[lgb_train, lgb_val],
        valid_names=["train", "val"],
        callbacks=callbacks,
    )
    
    # Dự báo trên tập test
    y_test_pred = model.predict(X_test, num_iteration=model.best_iteration)
    metrics_overall = compute_metrics(y_test, y_test_pred)
    
    # Metrics theo từng trạm
    df_test_res = meta_test.copy()
    df_test_res["y_true"] = y_test.values
    df_test_res["y_pred"] = y_test_pred
    
    rows = []
    for sid, grp in df_test_res.groupby("station_id"):
        m = compute_metrics(grp["y_true"], grp["y_pred"])
        rows.append({
            "station": int(sid),
            "horizon_h": horizon_h,
            **m,
        })
    metrics_by_station = pd.DataFrame(rows)
    
    return model, metrics_overall, metrics_by_station, (
        X_train, y_train, X_val, y_val, X_test, y_test, meta_test
    )

# %%
# === Cell 8: Train cho nhiều horizon & tổng hợp metrics ===

all_metrics = []
models_by_h = {}

for h in HORIZONS:
    print(f"\n===== Training LightGBM cho horizon = {h}h =====")
    model_h, metrics_overall, metrics_by_station, _ = train_lgbm_for_horizon(
        df_feat, horizon_h=h
    )
    models_by_h[h] = model_h
    print("Overall test metrics:", metrics_overall)
    all_metrics.append(metrics_by_station)

df_metrics_all = pd.concat(all_metrics, ignore_index=True)
df_metrics_all = df_metrics_all.sort_values(["station", "horizon_h"])
df_metrics_all
# Out:
# ===== Training LightGBM cho horizon = 1h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00348207	val's rmse: 0.00828111
# [200]	train's rmse: 0.00180404	val's rmse: 0.00825726
# Early stopping, best iteration is:
# [150]	train's rmse: 0.00247239	val's rmse: 0.00824109
# Overall test metrics: {'RMSE': 0.00986366184815793, 'MAE': 0.006980174384687494, 'MBE': -0.0005956429230662822, 'MNBE': 5.046293082500855, 'r': 0.8569493343662418, 'n_samples': 813}
#
# ===== Training LightGBM cho horizon = 2h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00397819	val's rmse: 0.0101221
# [200]	train's rmse: 0.001989	val's rmse: 0.0101339
# Early stopping, best iteration is:
# [126]	train's rmse: 0.00327192	val's rmse: 0.0100939
# Overall test metrics: {'RMSE': 0.011922723095286551, 'MAE': 0.008578459129938957, 'MBE': -0.002195450341008187, 'MNBE': 3.958304057687384, 'r': 0.7850070185524156, 'n_samples': 811}
#
# ===== Training LightGBM cho horizon = 3h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00412662	val's rmse: 0.0105909
# Early stopping, best iteration is:
# [91]	train's rmse: 0.00443369	val's rmse: 0.0105661
# Overall test metrics: {'RMSE': 0.012948702717222578, 'MAE': 0.009354308350815202, 'MBE': -0.0022004413087754913, 'MNBE': 4.9815372246615715, 'r': 0.7316907571327997, 'n_samples': 809}
#
# ===== Training LightGBM cho horizon = 4h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00408154	val's rmse: 0.0106359
# Early stopping, best iteration is:
# [67]	train's rmse: 0.00542719	val's rmse: 0.0106023
# Overall test metrics: {'RMSE': 0.013428581939937775, 'MAE': 0.009866228620162888, 'MBE': -0.0039719483637656, 'MNBE': 1.8790137291095264, 'r': 0.7190737837351321, 'n_samples': 808}
#
# ===== Training LightGBM cho horizon = 5h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00409564	val's rmse: 0.0106216
# Early stopping, best iteration is:
# [54]	train's rmse: 0.00616836	val's rmse: 0.0105498
# Overall test metrics: {'RMSE': 0.013296565001322175, 'MAE': 0.009841401379547157, 'MBE': -0.003726885313918736, 'MNBE': 2.364949273517567, 'r': 0.7241910265905797, 'n_samples': 806}
#
# ===== Training LightGBM cho horizon = 6h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00415055	val's rmse: 0.0107037
# Early stopping, best iteration is:
# [53]	train's rmse: 0.00622143	val's rmse: 0.0105994
# Overall test metrics: {'RMSE': 0.013233326365913834, 'MAE': 0.009814909706107539, 'MBE': -0.0032232040641919425, 'MNBE': 2.8469494592266775, 'r': 0.7185483714241534, 'n_samples': 804}
#
# ===== Training LightGBM cho horizon = 7h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00404343	val's rmse: 0.0106271
# Early stopping, best iteration is:
# [88]	train's rmse: 0.00446057	val's rmse: 0.0106074
# Overall test metrics: {'RMSE': 0.0131707790074753, 'MAE': 0.009866978289452148, 'MBE': -0.003713722573304396, 'MNBE': 1.407347437931053, 'r': 0.7183037403058378, 'n_samples': 803}
#
# ===== Training LightGBM cho horizon = 8h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00407876	val's rmse: 0.0106718
# Early stopping, best iteration is:
# [79]	train's rmse: 0.00487357	val's rmse: 0.0106001
# Overall test metrics: {'RMSE': 0.013168727492157192, 'MAE': 0.009829817052004579, 'MBE': -0.0035456220694974525, 'MNBE': 1.9064850422454458, 'r': 0.7192663537992056, 'n_samples': 801}
#
# ===== Training LightGBM cho horizon = 9h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00406661	val's rmse: 0.0105006
# Early stopping, best iteration is:
# [68]	train's rmse: 0.00532279	val's rmse: 0.0104326
# Overall test metrics: {'RMSE': 0.01345277886879258, 'MAE': 0.010042236146958865, 'MBE': -0.0035233405566074214, 'MNBE': 3.109352565920353, 'r': 0.717747260293014, 'n_samples': 798}
#
# ===== Training LightGBM cho horizon = 10h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00405243	val's rmse: 0.0103594
# Early stopping, best iteration is:
# [64]	train's rmse: 0.00552251	val's rmse: 0.0102899
# Overall test metrics: {'RMSE': 0.013612346299717689, 'MAE': 0.010323325938417439, 'MBE': -0.003527981277688657, 'MNBE': 3.7016664797186962, 'r': 0.714981789272526, 'n_samples': 797}
#
# ===== Training LightGBM cho horizon = 11h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.0040312	val's rmse: 0.0106544
# Early stopping, best iteration is:
# [73]	train's rmse: 0.00508125	val's rmse: 0.0105665
# Overall test metrics: {'RMSE': 0.013492231886946994, 'MAE': 0.01006408818427929, 'MBE': -0.003287784116036533, 'MNBE': 3.916291737343135, 'r': 0.7163292253190335, 'n_samples': 795}
#
# ===== Training LightGBM cho horizon = 12h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00409429	val's rmse: 0.0106305
# Early stopping, best iteration is:
# [68]	train's rmse: 0.0053667	val's rmse: 0.010537
# Overall test metrics: {'RMSE': 0.013408747665174576, 'MAE': 0.01010892491581711, 'MBE': -0.003153601236785777, 'MNBE': 4.03973129633469, 'r': 0.7287447553266413, 'n_samples': 793}
#
# ===== Training LightGBM cho horizon = 13h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00415314	val's rmse: 0.0103656
# Early stopping, best iteration is:
# [79]	train's rmse: 0.00497257	val's rmse: 0.0103347
# Overall test metrics: {'RMSE': 0.01320996001925874, 'MAE': 0.009921042126345567, 'MBE': -0.0030245006033634003, 'MNBE': 3.93415719392993, 'r': 0.7355112409810469, 'n_samples': 791}
#
# ===== Training LightGBM cho horizon = 14h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00411052	val's rmse: 0.0106201
# Early stopping, best iteration is:
# [84]	train's rmse: 0.00470218	val's rmse: 0.010611
# Overall test metrics: {'RMSE': 0.013536394902351681, 'MAE': 0.010265315236475815, 'MBE': -0.003565493545034934, 'MNBE': 3.3476971945024268, 'r': 0.7266677920421405, 'n_samples': 788}
#
# ===== Training LightGBM cho horizon = 15h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00408244	val's rmse: 0.0108509
# Early stopping, best iteration is:
# [70]	train's rmse: 0.005284	val's rmse: 0.0107835
# Overall test metrics: {'RMSE': 0.01361229179335662, 'MAE': 0.010348287868177748, 'MBE': -0.003476642923167094, 'MNBE': 3.5052650398008103, 'r': 0.7249184237442766, 'n_samples': 786}
#
# ===== Training LightGBM cho horizon = 16h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00410781	val's rmse: 0.010984
# Early stopping, best iteration is:
# [69]	train's rmse: 0.00535063	val's rmse: 0.0109546
# Overall test metrics: {'RMSE': 0.014384205708390708, 'MAE': 0.010940118891761578, 'MBE': -0.004697616412905184, 'MNBE': 1.799352662634502, 'r': 0.6947946495342805, 'n_samples': 784}
#
# ===== Training LightGBM cho horizon = 17h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00397335	val's rmse: 0.0111229
# Early stopping, best iteration is:
# [73]	train's rmse: 0.00501092	val's rmse: 0.0110743
# Overall test metrics: {'RMSE': 0.014242735541669025, 'MAE': 0.010889187454455784, 'MBE': -0.004545874352101, 'MNBE': 2.1817009856669127, 'r': 0.7038607650353839, 'n_samples': 782}
#
# ===== Training LightGBM cho horizon = 18h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00407945	val's rmse: 0.0109885
# Early stopping, best iteration is:
# [59]	train's rmse: 0.00585392	val's rmse: 0.0109324
# Overall test metrics: {'RMSE': 0.014475571385740968, 'MAE': 0.010972523058245937, 'MBE': -0.005562093439867476, 'MNBE': 0.7063980370199313, 'r': 0.7131622657485502, 'n_samples': 780}
#
# ===== Training LightGBM cho horizon = 19h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00412531	val's rmse: 0.0109897
# Early stopping, best iteration is:
# [57]	train's rmse: 0.00601293	val's rmse: 0.0109338
# Overall test metrics: {'RMSE': 0.014314012950614107, 'MAE': 0.010984430192178306, 'MBE': -0.005327876118893109, 'MNBE': 0.973531801250354, 'r': 0.7202395648946205, 'n_samples': 778}
#
# ===== Training LightGBM cho horizon = 20h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00420959	val's rmse: 0.0111729
# Early stopping, best iteration is:
# [56]	train's rmse: 0.0062068	val's rmse: 0.0111074
# Overall test metrics: {'RMSE': 0.01488751404550395, 'MAE': 0.01147266815178728, 'MBE': -0.005454721362011367, 'MNBE': 1.3729605618808771, 'r': 0.6970299003676627, 'n_samples': 776}
#
# ===== Training LightGBM cho horizon = 21h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00412934	val's rmse: 0.0112676
# Early stopping, best iteration is:
# [76]	train's rmse: 0.00504725	val's rmse: 0.0111902
# Overall test metrics: {'RMSE': 0.01490494529638948, 'MAE': 0.011471314156508093, 'MBE': -0.005285571250761524, 'MNBE': 1.578448741460161, 'r': 0.689198524910897, 'n_samples': 774}
#
# ===== Training LightGBM cho horizon = 22h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00413013	val's rmse: 0.0114887
# Early stopping, best iteration is:
# [74]	train's rmse: 0.0051708	val's rmse: 0.0114075
# Overall test metrics: {'RMSE': 0.014771795918843342, 'MAE': 0.011424324870125657, 'MBE': -0.0044228228100531095, 'MNBE': 3.1873357476383304, 'r': 0.6827108680952475, 'n_samples': 773}
#
# ===== Training LightGBM cho horizon = 23h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00418073	val's rmse: 0.0114026
# Early stopping, best iteration is:
# [55]	train's rmse: 0.00624012	val's rmse: 0.0112865
# Overall test metrics: {'RMSE': 0.014500219506982635, 'MAE': 0.01124112309037965, 'MBE': -0.004265880276552837, 'MNBE': 3.3956214242233953, 'r': 0.7023149959394699, 'n_samples': 771}
#
# ===== Training LightGBM cho horizon = 24h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00413029	val's rmse: 0.0115913
# Early stopping, best iteration is:
# [54]	train's rmse: 0.00619864	val's rmse: 0.0114647
# Overall test metrics: {'RMSE': 0.014382802924809429, 'MAE': 0.011099328185671218, 'MBE': -0.004196203124587302, 'MNBE': 3.6023781254857443, 'r': 0.7090634421310698, 'n_samples': 769}
#
# ===== Training LightGBM cho horizon = 25h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00410911	val's rmse: 0.0117865
# Early stopping, best iteration is:
# [77]	train's rmse: 0.00498879	val's rmse: 0.011739
# Overall test metrics: {'RMSE': 0.014306765433376707, 'MAE': 0.011114777248499049, 'MBE': -0.004766249426354378, 'MNBE': 2.639989968768232, 'r': 0.7261955037583939, 'n_samples': 767}
#
# ===== Training LightGBM cho horizon = 26h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00408456	val's rmse: 0.0118989
# Early stopping, best iteration is:
# [85]	train's rmse: 0.00462587	val's rmse: 0.0118674
# Overall test metrics: {'RMSE': 0.014411370356710895, 'MAE': 0.011207189455440044, 'MBE': -0.00499058800361909, 'MNBE': 2.1521982847021803, 'r': 0.7187707042296181, 'n_samples': 766}
#
# ===== Training LightGBM cho horizon = 27h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00402918	val's rmse: 0.012023
# Early stopping, best iteration is:
# [63]	train's rmse: 0.00560596	val's rmse: 0.0119498
# Overall test metrics: {'RMSE': 0.014648700763904956, 'MAE': 0.011358878213503993, 'MBE': -0.005299176428525464, 'MNBE': 1.7838732591045723, 'r': 0.7023321008583251, 'n_samples': 765}
#
# ===== Training LightGBM cho horizon = 28h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401757	val's rmse: 0.0115161
# Early stopping, best iteration is:
# [82]	train's rmse: 0.00469095	val's rmse: 0.0114878
# Overall test metrics: {'RMSE': 0.014556101170778967, 'MAE': 0.0113212065117039, 'MBE': -0.0057628237678639714, 'MNBE': 0.3770653938027234, 'r': 0.7064848992620989, 'n_samples': 764}
#
# ===== Training LightGBM cho horizon = 29h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401718	val's rmse: 0.011254
# Early stopping, best iteration is:
# [58]	train's rmse: 0.00589111	val's rmse: 0.0111269
# Overall test metrics: {'RMSE': 0.014449850227337623, 'MAE': 0.011187358415670827, 'MBE': -0.005946666361943705, 'MNBE': 0.40791742219810523, 'r': 0.7205940257905503, 'n_samples': 763}
#
# ===== Training LightGBM cho horizon = 30h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401452	val's rmse: 0.0110979
# Early stopping, best iteration is:
# [67]	train's rmse: 0.00538824	val's rmse: 0.0110293
# Overall test metrics: {'RMSE': 0.014355006399285079, 'MAE': 0.011092806755989516, 'MBE': -0.005803295223065916, 'MNBE': 0.7516977375393719, 'r': 0.7198697577656734, 'n_samples': 762}
#
# ===== Training LightGBM cho horizon = 31h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00395657	val's rmse: 0.0111513
# Early stopping, best iteration is:
# [61]	train's rmse: 0.00565965	val's rmse: 0.0110343
# Overall test metrics: {'RMSE': 0.014151280933625257, 'MAE': 0.0108868461996259, 'MBE': -0.005582567406610903, 'MNBE': 0.646424512712521, 'r': 0.7197803619154041, 'n_samples': 761}
#
# ===== Training LightGBM cho horizon = 32h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401519	val's rmse: 0.0111629
# Early stopping, best iteration is:
# [78]	train's rmse: 0.00484654	val's rmse: 0.0111204
# Overall test metrics: {'RMSE': 0.014180841733355865, 'MAE': 0.011085193968097873, 'MBE': -0.005779020329029068, 'MNBE': -0.10763701041487653, 'r': 0.7212719137432699, 'n_samples': 760}
#
# ===== Training LightGBM cho horizon = 33h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00395593	val's rmse: 0.011103
# [200]	train's rmse: 0.00190771	val's rmse: 0.011197
# Early stopping, best iteration is:
# [106]	train's rmse: 0.00376225	val's rmse: 0.0110923
# Overall test metrics: {'RMSE': 0.014652964840840093, 'MAE': 0.01149828597784227, 'MBE': -0.00641959187631249, 'MNBE': -0.8535538551361996, 'r': 0.7081603842305595, 'n_samples': 759}
#
# ===== Training LightGBM cho horizon = 34h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00396969	val's rmse: 0.0111983
# Early stopping, best iteration is:
# [65]	train's rmse: 0.00537464	val's rmse: 0.0111081
# Overall test metrics: {'RMSE': 0.014971507749902776, 'MAE': 0.011721662787439018, 'MBE': -0.006712411777924905, 'MNBE': -0.8386154356585875, 'r': 0.7058254402706048, 'n_samples': 759}
#
# ===== Training LightGBM cho horizon = 35h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00396586	val's rmse: 0.0111305
# Early stopping, best iteration is:
# [84]	train's rmse: 0.00452913	val's rmse: 0.0111146
# Overall test metrics: {'RMSE': 0.014472548776974474, 'MAE': 0.011132804062872289, 'MBE': -0.005687346312378774, 'MNBE': 0.348188148372514, 'r': 0.6975910672877672, 'n_samples': 758}
#
# ===== Training LightGBM cho horizon = 36h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00400185	val's rmse: 0.0113848
# Early stopping, best iteration is:
# [52]	train's rmse: 0.00620844	val's rmse: 0.0112474
# Overall test metrics: {'RMSE': 0.015200091371803694, 'MAE': 0.0118083944411644, 'MBE': -0.006356038219178301, 'MNBE': -0.07226613867643727, 'r': 0.6848091587077019, 'n_samples': 757}
#
# ===== Training LightGBM cho horizon = 37h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401068	val's rmse: 0.011272
# Early stopping, best iteration is:
# [67]	train's rmse: 0.00534861	val's rmse: 0.0111842
# Overall test metrics: {'RMSE': 0.015021778529747268, 'MAE': 0.011685769006351073, 'MBE': -0.00651052439775051, 'MNBE': -0.8112751994155152, 'r': 0.7050034881781811, 'n_samples': 757}
#
# ===== Training LightGBM cho horizon = 38h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00405498	val's rmse: 0.011017
# Early stopping, best iteration is:
# [79]	train's rmse: 0.00487015	val's rmse: 0.0109587
# Overall test metrics: {'RMSE': 0.014904919403448165, 'MAE': 0.011610828072416443, 'MBE': -0.006094798821725278, 'MNBE': -0.010535878732732193, 'r': 0.6945663255332662, 'n_samples': 756}
#
# ===== Training LightGBM cho horizon = 39h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401759	val's rmse: 0.0112886
# Early stopping, best iteration is:
# [91]	train's rmse: 0.00432686	val's rmse: 0.0112741
# Overall test metrics: {'RMSE': 0.015294081542954543, 'MAE': 0.011949448390357333, 'MBE': -0.0068775319628410275, 'MNBE': -1.2361295813396476, 'r': 0.6920025535614831, 'n_samples': 756}
#
# ===== Training LightGBM cho horizon = 40h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00403091	val's rmse: 0.0114302
# Early stopping, best iteration is:
# [48]	train's rmse: 0.00647444	val's rmse: 0.0112719
# Overall test metrics: {'RMSE': 0.015270347245217615, 'MAE': 0.01199726846902026, 'MBE': -0.006494101478714931, 'MNBE': -0.039503971922086885, 'r': 0.7053430176808115, 'n_samples': 755}
#
# ===== Training LightGBM cho horizon = 41h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00400047	val's rmse: 0.0110638
# [200]	train's rmse: 0.00191043	val's rmse: 0.0111055
# Early stopping, best iteration is:
# [141]	train's rmse: 0.00290285	val's rmse: 0.0110547
# Overall test metrics: {'RMSE': 0.015453458457794111, 'MAE': 0.01215961959924591, 'MBE': -0.006700912792524553, 'MNBE': -0.6807924505727653, 'r': 0.6747791624983008, 'n_samples': 755}
#
# ===== Training LightGBM cho horizon = 42h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00395636	val's rmse: 0.0113518
# Early stopping, best iteration is:
# [75]	train's rmse: 0.00492813	val's rmse: 0.0113246
# Overall test metrics: {'RMSE': 0.015737895379709193, 'MAE': 0.012368110463986776, 'MBE': -0.006877507080908358, 'MNBE': -0.689100548520823, 'r': 0.6646251395344194, 'n_samples': 754}
#
# ===== Training LightGBM cho horizon = 43h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.0040347	val's rmse: 0.0112448
# Early stopping, best iteration is:
# [58]	train's rmse: 0.00591319	val's rmse: 0.011136
# Overall test metrics: {'RMSE': 0.01523560797165442, 'MAE': 0.011738671147412602, 'MBE': -0.006662004861271259, 'MNBE': -0.31612082952179793, 'r': 0.6967994032837883, 'n_samples': 754}
#
# ===== Training LightGBM cho horizon = 44h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00403145	val's rmse: 0.0117637
# Early stopping, best iteration is:
# [60]	train's rmse: 0.00577241	val's rmse: 0.0116165
# Overall test metrics: {'RMSE': 0.01634775710777319, 'MAE': 0.012760635197596541, 'MBE': -0.007816740103552575, 'MNBE': -1.716609115322338, 'r': 0.6505311988640121, 'n_samples': 753}
#
# ===== Training LightGBM cho horizon = 45h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401389	val's rmse: 0.01163
# Early stopping, best iteration is:
# [60]	train's rmse: 0.00576189	val's rmse: 0.0114991
# Overall test metrics: {'RMSE': 0.015859287387273904, 'MAE': 0.012520265575500485, 'MBE': -0.007109498958949536, 'MNBE': -0.6661499629033831, 'r': 0.6784094586399309, 'n_samples': 753}
#
# ===== Training LightGBM cho horizon = 46h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00405242	val's rmse: 0.011883
# Early stopping, best iteration is:
# [62]	train's rmse: 0.0056911	val's rmse: 0.0117739
# Overall test metrics: {'RMSE': 0.01580601059173061, 'MAE': 0.012442169879477499, 'MBE': -0.006872757865443775, 'MNBE': -0.31413155601398335, 'r': 0.6717303656706912, 'n_samples': 752}
#
# ===== Training LightGBM cho horizon = 47h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00405843	val's rmse: 0.0114409
# Early stopping, best iteration is:
# [55]	train's rmse: 0.00607972	val's rmse: 0.0113529
# Overall test metrics: {'RMSE': 0.015076196024041229, 'MAE': 0.011890533740859657, 'MBE': -0.006516103501845122, 'MNBE': -0.3585863386838672, 'r': 0.718089492030272, 'n_samples': 752}
#
# ===== Training LightGBM cho horizon = 48h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00405809	val's rmse: 0.0115853
# Early stopping, best iteration is:
# [75]	train's rmse: 0.0050168	val's rmse: 0.0115678
# Overall test metrics: {'RMSE': 0.014821780283468863, 'MAE': 0.011644518896871169, 'MBE': -0.006486884483298911, 'MNBE': -0.8406434367964571, 'r': 0.7281139853434094, 'n_samples': 751}
#
# ===== Training LightGBM cho horizon = 49h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00407064	val's rmse: 0.012089
# Early stopping, best iteration is:
# [57]	train's rmse: 0.0059808	val's rmse: 0.0120395
# Overall test metrics: {'RMSE': 0.014728301543520565, 'MAE': 0.011480199026351778, 'MBE': -0.006237952997406788, 'MNBE': -0.21304963369878074, 'r': 0.7408014245065838, 'n_samples': 751}
#
# ===== Training LightGBM cho horizon = 50h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00412387	val's rmse: 0.0121648
# Early stopping, best iteration is:
# [66]	train's rmse: 0.00556052	val's rmse: 0.012105
# Overall test metrics: {'RMSE': 0.015256070797513822, 'MAE': 0.011898396437191167, 'MBE': -0.0068631842009685496, 'MNBE': -1.187525431914984, 'r': 0.7027115771283473, 'n_samples': 750}
#
# ===== Training LightGBM cho horizon = 51h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00403461	val's rmse: 0.0120285
# Early stopping, best iteration is:
# [45]	train's rmse: 0.00685536	val's rmse: 0.0119543
# Overall test metrics: {'RMSE': 0.015658235012017963, 'MAE': 0.012121597873360278, 'MBE': -0.006783582861287391, 'MNBE': -0.4017146291310134, 'r': 0.6652918005922038, 'n_samples': 750}
#
# ===== Training LightGBM cho horizon = 52h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00400579	val's rmse: 0.0120416
# Early stopping, best iteration is:
# [48]	train's rmse: 0.006539	val's rmse: 0.0119854
# Overall test metrics: {'RMSE': 0.01546892494019826, 'MAE': 0.012069833496524997, 'MBE': -0.007376617451255835, 'MNBE': -2.122226143267448, 'r': 0.686240848373695, 'n_samples': 749}
#
# ===== Training LightGBM cho horizon = 53h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00403345	val's rmse: 0.0119529
# Early stopping, best iteration is:
# [44]	train's rmse: 0.00686712	val's rmse: 0.0117453
# Overall test metrics: {'RMSE': 0.015219216553680606, 'MAE': 0.011928061920615412, 'MBE': -0.007148982732149061, 'MNBE': -2.029379809409959, 'r': 0.700051192716657, 'n_samples': 749}
#
# ===== Training LightGBM cho horizon = 54h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00400965	val's rmse: 0.0116934
# Early stopping, best iteration is:
# [51]	train's rmse: 0.0063373	val's rmse: 0.011464
# Overall test metrics: {'RMSE': 0.014838778248797882, 'MAE': 0.011566141948535662, 'MBE': -0.0068978627461252, 'MNBE': -1.6978759809939643, 'r': 0.7118494458845952, 'n_samples': 748}
#
# ===== Training LightGBM cho horizon = 55h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00398981	val's rmse: 0.0116789
# Early stopping, best iteration is:
# [62]	train's rmse: 0.00564731	val's rmse: 0.0115326
# Overall test metrics: {'RMSE': 0.014771731304174342, 'MAE': 0.011433635145225088, 'MBE': -0.00694453448559666, 'MNBE': -1.679562158530871, 'r': 0.7108496139464111, 'n_samples': 747}
#
# ===== Training LightGBM cho horizon = 56h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.0039428	val's rmse: 0.0118006
# Early stopping, best iteration is:
# [36]	train's rmse: 0.00750478	val's rmse: 0.0116693
# Overall test metrics: {'RMSE': 0.014824849230720557, 'MAE': 0.0115177948802962, 'MBE': -0.006469355332138324, 'MNBE': -0.6390727405807065, 'r': 0.7082898353226325, 'n_samples': 747}
#
# ===== Training LightGBM cho horizon = 57h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00390849	val's rmse: 0.0117495
# Early stopping, best iteration is:
# [48]	train's rmse: 0.00640607	val's rmse: 0.0115643
# Overall test metrics: {'RMSE': 0.015065278779844428, 'MAE': 0.011776488515313004, 'MBE': -0.007652340504848041, 'MNBE': -2.906382589066083, 'r': 0.7122876664874387, 'n_samples': 746}
#
# ===== Training LightGBM cho horizon = 58h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00396937	val's rmse: 0.011483
# Early stopping, best iteration is:
# [56]	train's rmse: 0.00587703	val's rmse: 0.0113426
# Overall test metrics: {'RMSE': 0.015334413733263769, 'MAE': 0.011954004286812177, 'MBE': -0.007512814574301992, 'MNBE': -2.519921549273753, 'r': 0.6877417110191228, 'n_samples': 745}
#
# ===== Training LightGBM cho horizon = 59h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00392508	val's rmse: 0.0115952
# Early stopping, best iteration is:
# [55]	train's rmse: 0.00590312	val's rmse: 0.0114614
# Overall test metrics: {'RMSE': 0.01529604205331116, 'MAE': 0.011858328073773036, 'MBE': -0.00757645456505544, 'MNBE': -2.69611646260139, 'r': 0.6948966763535783, 'n_samples': 744}
#
# ===== Training LightGBM cho horizon = 60h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00399389	val's rmse: 0.0116068
# Early stopping, best iteration is:
# [51]	train's rmse: 0.0062937	val's rmse: 0.0114602
# Overall test metrics: {'RMSE': 0.015457853269085673, 'MAE': 0.012001693059152687, 'MBE': -0.0073246364212481065, 'MNBE': -1.7214840851453959, 'r': 0.6794847774274798, 'n_samples': 743}
#
# ===== Training LightGBM cho horizon = 61h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401934	val's rmse: 0.0115783
# Early stopping, best iteration is:
# [53]	train's rmse: 0.00617085	val's rmse: 0.011468
# Overall test metrics: {'RMSE': 0.014958552039878392, 'MAE': 0.011565836220967192, 'MBE': -0.006758072557111047, 'MNBE': -1.1528057670239416, 'r': 0.7042063877022663, 'n_samples': 742}
#
# ===== Training LightGBM cho horizon = 62h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00399064	val's rmse: 0.0116421
# Early stopping, best iteration is:
# [39]	train's rmse: 0.00717558	val's rmse: 0.0115156
# Overall test metrics: {'RMSE': 0.015116130638271618, 'MAE': 0.011714363580917287, 'MBE': -0.00686297652515467, 'MNBE': -0.9062109752133243, 'r': 0.704633998333756, 'n_samples': 741}
#
# ===== Training LightGBM cho horizon = 63h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00392757	val's rmse: 0.011827
# Early stopping, best iteration is:
# [51]	train's rmse: 0.00619974	val's rmse: 0.0116244
# Overall test metrics: {'RMSE': 0.015069133527544624, 'MAE': 0.011630961323109444, 'MBE': -0.0068327781491087985, 'MNBE': -1.2870372607154845, 'r': 0.692406428756239, 'n_samples': 740}
#
# ===== Training LightGBM cho horizon = 64h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.0040385	val's rmse: 0.0117194
# Early stopping, best iteration is:
# [54]	train's rmse: 0.00609311	val's rmse: 0.0115369
# Overall test metrics: {'RMSE': 0.015109304455696023, 'MAE': 0.011629488848300932, 'MBE': -0.006872997194307292, 'MNBE': -1.1244202210078627, 'r': 0.6876091699659441, 'n_samples': 739}
#
# ===== Training LightGBM cho horizon = 65h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00396425	val's rmse: 0.011944
# Early stopping, best iteration is:
# [57]	train's rmse: 0.00586088	val's rmse: 0.0118428
# Overall test metrics: {'RMSE': 0.015105888354838478, 'MAE': 0.011673489829208867, 'MBE': -0.007000545189768156, 'MNBE': -1.462775824561893, 'r': 0.6910751523186923, 'n_samples': 739}
#
# ===== Training LightGBM cho horizon = 66h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00391469	val's rmse: 0.0120082
# Early stopping, best iteration is:
# [54]	train's rmse: 0.00605635	val's rmse: 0.0118515
# Overall test metrics: {'RMSE': 0.014981187524956465, 'MAE': 0.01160386321030157, 'MBE': -0.007015142591836793, 'MNBE': -1.341686670218922, 'r': 0.7045151913435614, 'n_samples': 738}
#
# ===== Training LightGBM cho horizon = 67h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00398165	val's rmse: 0.0117429
# Early stopping, best iteration is:
# [54]	train's rmse: 0.00610743	val's rmse: 0.0115922
# Overall test metrics: {'RMSE': 0.015210425165377973, 'MAE': 0.0117751301839644, 'MBE': -0.00728015669501786, 'MNBE': -2.016064459810624, 'r': 0.6915894414603722, 'n_samples': 737}
#
# ===== Training LightGBM cho horizon = 68h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00400889	val's rmse: 0.0119823
# Early stopping, best iteration is:
# [67]	train's rmse: 0.00539281	val's rmse: 0.0118423
# Overall test metrics: {'RMSE': 0.015308252177043607, 'MAE': 0.011878510262625762, 'MBE': -0.007591122860412434, 'MNBE': -2.8917138803048417, 'r': 0.6827512830905349, 'n_samples': 737}
#
# ===== Training LightGBM cho horizon = 69h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00401757	val's rmse: 0.0118075
# Early stopping, best iteration is:
# [67]	train's rmse: 0.00541838	val's rmse: 0.0116945
# Overall test metrics: {'RMSE': 0.015287641342209828, 'MAE': 0.01183468995202066, 'MBE': -0.007657081502816837, 'MNBE': -3.0434529854661365, 'r': 0.6853556540626197, 'n_samples': 737}
#
# ===== Training LightGBM cho horizon = 70h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00398101	val's rmse: 0.0115937
# Early stopping, best iteration is:
# [60]	train's rmse: 0.00576291	val's rmse: 0.0113917
# Overall test metrics: {'RMSE': 0.015275789177078053, 'MAE': 0.01188103576592303, 'MBE': -0.007557658657066254, 'MNBE': -2.588419187295439, 'r': 0.6882528527142275, 'n_samples': 736}
#
# ===== Training LightGBM cho horizon = 71h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00397677	val's rmse: 0.0116806
# Early stopping, best iteration is:
# [48]	train's rmse: 0.00648815	val's rmse: 0.011525
# Overall test metrics: {'RMSE': 0.01530160447328255, 'MAE': 0.011915095133025614, 'MBE': -0.0070691479645074275, 'MNBE': -1.6007187351180185, 'r': 0.6743900861150041, 'n_samples': 735}
#
# ===== Training LightGBM cho horizon = 72h =====
# Training until validation scores don't improve for 100 rounds
# [100]	train's rmse: 0.00396719	val's rmse: 0.0114939
# Early stopping, best iteration is:
# [59]	train's rmse: 0.00576649	val's rmse: 0.0113998
# Overall test metrics: {'RMSE': 0.0159503401867405, 'MAE': 0.012660688851178475, 'MBE': -0.007812719982158102, 'MNBE': -2.3536648418859425, 'r': 0.6499225645272229, 'n_samples': 735}
#     station  horizon_h      RMSE       MAE       MBE      MNBE         r  \
# 0       216          1  0.009864  0.006980 -0.000596  5.046293  0.856949
# 1       216          2  0.011923  0.008578 -0.002195  3.958304  0.785007
# 2       216          3  0.012949  0.009354 -0.002200  4.981537  0.731691
# 3       216          4  0.013429  0.009866 -0.003972  1.879014  0.719074
# 4       216          5  0.013297  0.009841 -0.003727  2.364949  0.724191
# ..      ...        ...       ...       ...       ...       ...       ...
# 67      216         68  0.015308  0.011879 -0.007591 -2.891714  0.682751
# 68      216         69  0.015288  0.011835 -0.007657 -3.043453  0.685356
# 69      216         70  0.015276  0.011881 -0.007558 -2.588419  0.688253
# 70      216         71  0.015302  0.011915 -0.007069 -1.600719  0.674390
# 71      216         72  0.015950  0.012661 -0.007813 -2.353665  0.649923
#
#     n_samples
# 0         813
# 1         811
# 2         809
# 3         808
# 4         806
# ..        ...
# 67        737
# 68        737
# 69        736
# 70        735
# 71        735
#
# [72 rows x 8 columns]

# %%
# === Cell 9: Vẽ y_true vs y_pred theo thời gian cho 1 station & 1 horizon ===

def plot_timeseries_example(df_feat, model, horizon_h, station_id,
                            n_points=300):
    # Build dataset
    X, y, meta, feat_cols = build_supervised_for_horizon(df_feat, horizon_h)
    (_, _, _,
     _, _, _,
     X_test, y_test, meta_test) = time_based_split(X, y, meta)
    print(y_test)
    
    # Chọn riêng station_id
    mask = (meta_test["station_id"] == station_id)
    print(meta_test)
    print(mask)
    X_test_sid = X_test[mask]
    y_test_sid = y_test[mask]
    meta_sid = meta_test[mask]
    
    if len(X_test_sid) == 0:
        print("Không có mẫu test cho station", station_id)
        return
    
    y_pred_sid = model.predict(X_test_sid, num_iteration=getattr(model, "best_iteration", None))
    
    # Chỉ vẽ n_points cuối cho dễ nhìn
    X_plot = meta_sid.iloc[-n_points:]
    y_true_plot = y_test_sid.iloc[-n_points:]
    y_pred_plot = y_pred_sid[-n_points:]
    
    plt.figure(figsize=(14, 5))
    plt.plot(X_plot["date"], y_true_plot, label="NO2 thực", linewidth=1.5)
    plt.plot(X_plot["date"], y_pred_plot, label="NO2 dự báo (LightGBM)", linestyle="--")
    plt.title(f"Station {station_id} - Horizon {horizon_h}h")
    plt.xlabel("Thời gian")
    plt.ylabel("NO2 (µg/m³)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Ví dụ: vẽ cho trạm 211, horizon = 1
plot_timeseries_example(df_feat, models_by_h[72], horizon_h=72, station_id=216)
# Out:
# 91873    0.068767
# 91874    0.069233
# 91875    0.061517
# 91876    0.060433
# 91877    0.068650
#            ...
# 92889    0.088233
# 92890    0.083217
# 92891    0.084300
# 92892    0.066650
# 92893    0.067783
# Name: NO2_quantrac_t_plus_72h, Length: 735, dtype: float64
#                      date  station_id
# 91873 2022-11-16 11:00:00         216
# 91874 2022-11-16 12:00:00         216
# 91875 2022-11-16 13:00:00         216
# 91876 2022-11-16 14:00:00         216
# 91877 2022-11-16 15:00:00         216
# ...                   ...         ...
# 92889 2022-12-28 19:00:00         216
# 92890 2022-12-28 20:00:00         216
# 92891 2022-12-28 21:00:00         216
# 92892 2022-12-28 22:00:00         216
# 92893 2022-12-28 23:00:00         216
#
# [735 rows x 2 columns]
# 91873    True
# 91874    True
# 91875    True
# 91876    True
# 91877    True
#          ...
# 92889    True
# 92890    True
# 92891    True
# 92892    True
# 92893    True
# Name: station_id, Length: 735, dtype: bool
