# %%
import pandas as pd
import numpy as np

def mnbe(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    return np.mean((y_pred - y_true) / np.mean(y_true)) * 100

# %%
df_raw = pd.read_csv("df_aod_raw.csv")
df_raw
# Out:
#             time  station       pm25        lat         lon   pm25_3km  \
# 0     2018-01-01      201  31.391304  10.783057  106.700606  34.919998
# 1     2018-01-02      201  37.458333  10.783057  106.700606  51.830002
# 2     2018-01-03      201  68.083333  10.783057  106.700606  38.240002
# 3     2018-01-04      201  51.260870  10.783057  106.700606  40.259998
# 4     2018-01-05      201  18.909091  10.783057  106.700606  21.690001
# ...          ...      ...        ...        ...         ...        ...
# 3884  2022-12-27      216  39.659816  10.780482  106.659511  34.439411
# 3885  2022-12-28      216  44.679352  10.780482  106.659511  29.838476
# 3886  2022-12-29      216  30.724708  10.780482  106.659511  28.450829
# 3887  2022-12-30      216  33.091428  10.780482  106.659511  19.854403
# 3888  2022-12-31      216  28.854069  10.780482  106.659511  27.658358
#
#             tmp         rh        hpbl      wspd  ...  prim_road_len_1km  \
# ...

# %%
df_lstms2s_predicted = pd.read_csv("/le_thanh_van_118/workspace/hiep_workspace/best_reduced_data/df_lstms2s_reduced_2021_2022_with_raw_pm25_3km_and_prediced_pm25.csv")
display(df_lstms2s_predicted)

print(f"MNBE = {mnbe(df_raw['pm25'], df_lstms2s_predicted['hiep_predicted_pm25'])}")
# Out:
#             time  aod_feature_1  aod_feature_2  aod_feature_3  aod_feature_4  \
# 0     2018-01-01       0.500994       0.933539       1.112934       0.561353
# 1     2018-01-02       0.500994       0.933539       1.112934       0.561353
# 2     2018-01-03       0.501392       0.935029       1.114251       0.563723
# 3     2018-01-04       0.502023       0.943688       1.119303       0.572449
# 4     2018-01-05       0.503770       0.955540       1.128586       0.583927
# ...          ...            ...            ...            ...            ...
# 3884  2022-12-27       0.291518       0.278929       0.556140       0.344859
# 3885  2022-12-28       0.290609       0.274245       0.552987       0.340629
# 3886  2022-12-29       0.286391       0.266631       0.542333       0.334289
# 3887  2022-12-30       0.285750       0.263025       0.540469       0.329861
# 3888  2022-12-31       0.286938       0.264819       0.544376       0.329837
#
# ...

# %%
df_grus2s_predicted = pd.read_csv("/le_thanh_van_118/workspace/hiep_workspace/best_reduced_data/df_grus2s_reduced_2021_2022_with_raw_pm25_3km_and_prediced_pm25.csv")
display(df_grus2s_predicted)

print(f"MNBE = {mnbe(df_raw['pm25'], df_grus2s_predicted['hiep_predicted_pm25'])}")
# Out:
#             time  aod_feature_1  aod_feature_2  aod_feature_3  aod_feature_4  \
# 0     2018-01-01       0.027778       0.084455       0.034190       0.032235
# 1     2018-01-02       0.027778       0.084455       0.034190       0.032235
# 2     2018-01-03       0.027512       0.085002       0.034248       0.032085
# 3     2018-01-04       0.027185       0.085771       0.034107       0.031513
# 4     2018-01-05       0.026951       0.085912       0.033957       0.031276
# ...          ...            ...            ...            ...            ...
# 3884  2022-12-27       0.053607       0.083945       0.047260       0.083631
# 3885  2022-12-28       0.053371       0.084009       0.047256       0.083982
# 3886  2022-12-29       0.053795       0.083575       0.047343       0.083484
# 3887  2022-12-30       0.053997       0.083271       0.047338       0.082584
# 3888  2022-12-31       0.054037       0.083296       0.047187       0.082762
#
# ...

# %%
df_cnnlstms2s_predicted = pd.read_csv("/le_thanh_van_118/workspace/hiep_workspace/best_reduced_data/df_cnnlstms2s_reduced_2021_2022_with_raw_pm25_3km_and_prediced_pm25.csv")
display(df_cnnlstms2s_predicted)

print(f"MNBE = {mnbe(df_raw['pm25'], df_cnnlstms2s_predicted['hiep_predicted_pm25'])}")
# Out:
#             time  aod_feature_1  aod_feature_2  aod_feature_3  aod_feature_4  \
# 0     2018-01-01       0.199706       0.178301       0.242002      -0.343510
# 1     2018-01-02       0.199706       0.178301       0.242002      -0.343510
# 2     2018-01-03       0.199706       0.178301       0.242002      -0.343510
# 3     2018-01-04       0.199706       0.178301       0.242002      -0.343510
# 4     2018-01-05       0.200187       0.177504       0.245416      -0.345525
# ...          ...            ...            ...            ...            ...
# 3884  2022-12-27       0.053943       0.079293      -0.170026       0.033377
# 3885  2022-12-28       0.060726       0.081919      -0.166246       0.029047
# 3886  2022-12-29       0.061780       0.088712      -0.158851       0.014501
# 3887  2022-12-30       0.060368       0.082157      -0.152829       0.019925
# 3888  2022-12-31       0.057878       0.082536      -0.160422       0.023697
#
# ...
